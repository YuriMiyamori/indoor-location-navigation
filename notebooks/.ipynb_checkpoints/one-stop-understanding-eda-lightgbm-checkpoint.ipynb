# %% [markdown]
# <h1><center>Indoor Location & Navigation</h1></center>
# <h2><center>Identify the position of a smartphone in a shopping mall</h2></center>

# %% [markdown]
# <b>In this notebook I have tried my best to explain all the topics/aspects, related to this competition, at easiest form. </b>

# %% [markdown]
# <center><h2>Understand The Competition</center></h2>
# Our smartphone goes everywhere with us and with permission, apps can use our location to provide contextual information. We get driving directions, find a store, or receive alerts for nearby promotions. These handy features are enabled by GPS, which requires outdoor exposure for the best accuracy.
#
# Current positioning solutions have poor accuracy, particularly in multi-level buildings.
#
# <b>In this competition, our task is to predict the indoor position of smartphones based on real-time sensor data.</b>

# %%
# Libraries
import numpy as np # linear algebra
import pandas as pd # data processing
import os
import json
import random
import glob
import seaborn as sns
from pathlib import Path
from PIL import Image, ImageOps
import matplotlib.pyplot as plt
import scipy.stats as stats
from sklearn.model_selection import KFold
import lightgbm as lgb
import psutil
import random
import os
import time
import sys
import math
from contextlib import contextmanager

# %% [markdown]
# <h2>Understand the Data</h2>
# First, we need to understand the input data. The folder "indoor-location-navigation" contains 3 subdirectories, "metadata", "test", and "train", respectively.
# The following schematic shows the data structure in the "metadata" folder, as it is given in the "Data Description" tab.

# %% [markdown]
# ![Kaggle Indoor Location.PNG](attachment:b5ac40a4-c8da-493d-ad9a-c1a3c0b5f920.PNG)

# %% [markdown]
# We are going to use the images in the .png format to display the locations. The other two files associated with each floor are in .json format. The floor_info.json describes the size of the location (height and width), while the geojson_map.json is a file for geospatial visualization (it is possible to reproduce a raster image in .png format using the *geopandas* library applied to this .json file).

# %% [markdown]
# <h2>Data Organization</h2>
#
# <h4>Training Dataset</h4>

# %%
dataset_path = Path('../../indoor-location-navigation')
os.listdir(dataset_path)
# Out:
# ['train', 'notebooks', 'test', 'metadata']

# %% [markdown]
# <b>Note that the data is organized by the sites and floors. Let's see how many sites do we have in train dataset?</b>

# %%
train_sites = os.listdir(dataset_path/"train")
print(f'There are {len(train_sites)} sites in the training set')
# Out:
# There are 204 sites in the training set

# %% [markdown]
# ## Now each site is organized by Floors

# %%
example_site = os.listdir(dataset_path/"train")[12]
example_site_path = dataset_path/"train"/example_site
print('Floors for example site:')
print(os.listdir(example_site_path))
# Out:
# Floors for example site:
# ['F2', 'F1', 'B1', 'B2']

# %%
floors_per_site = []
for i in os.listdir(dataset_path/"train"): floors_per_site.append(len(os.listdir(dataset_path/"train"/i)))
print(f'There are a total of {sum(floors_per_site)} floors. On average, each site has {np.mean(floors_per_site)} floors')
# Out:
# There are a total of 981 floors. On average, each site has 4.8088235294117645 floors

# %% [markdown]
# <b>So every site has about 5 floors. In each floor are the path trace text files with the data</b>

# %% [markdown]
# <b>Path File</b>

# %%
print('Path text files for example floor:')
print(os.listdir(example_site_path/'B1'))
# Out:
# Path text files for example floor:
# ['5d08da465ded320009ea9cf4.txt']

# %% [markdown]
# <h4>Train Data path files count</h4>

# %%
print(f"There are {len(list((dataset_path/'train').rglob('*.txt')))} path text files in the training set")
# Out:
# There are 26925 path text files in the training set

# %% [markdown]
# <b>To summarize, this is how the training data is structured:</b>

# %% [markdown]
# ```
# └───train                                                        //raw data from two sites
#       └───site1
#       |     └───B1                                               //traces from one floor
#       |     |   └───5dda14a2c5b77e0006b17533.txt                 //trace file
#       |     |   | ...
#       |     |
#       |     |
#       |     └───F1
#       |     | ...
#       |
#       └───site2
# ```

# %% [markdown]
# <h4>Test Dataset</h4>

# %%
print(f"There are {len(os.listdir(dataset_path/'test'))} path text files in the test set")
# Out:
# There are 626 path text files in the test set

# %% [markdown]
# <h4>Metdata Organization</h4>

# %%
print(f'There are {len(os.listdir(dataset_path/"metadata"))} sites in the metadata, just like the training set')
# Out:
# There are 204 sites in the metadata, just like the training set

# %% [markdown]
# <b>Let's look at a single floor of a single site</b>

# %%
metadata_example_site = os.listdir(dataset_path/"metadata")[10]
metadata_example_site_path = dataset_path/"metadata"/metadata_example_site
metadata_example_floor_path = dataset_path/"metadata"/metadata_example_site/os.listdir(metadata_example_site_path)[0]
print(os.listdir(metadata_example_floor_path))
# Out:
# ['geojson_map.json', 'floor_info.json', 'floor_image.png']

# %% [markdown]
# <b>Explore 'floor_image.png' file</b>

# %%
Image.open(metadata_example_floor_path/'floor_image.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=800x866 at 0x7FBF37C7DCD0>

# %% [markdown]
# <b>Explore 'geojson_map.json' file</b>

# %%
##################### In comment because Large Output Data ########################


# with open(metadata_example_floor_path/'geojson_map.json') as geojson_map:
#     data = json.load(geojson_map)
#     geojson_map.close()
# print(data)

# %% [markdown]
# <b>Explore 'floor_info.json' file</b>

# %%
with open(metadata_example_floor_path/'floor_info.json') as floor_info:
    data = json.load(floor_info)
    floor_info.close()
print(data)
# Out:
# {'map_info': {'height': 87.38594140488213, 'width': 80.68509275477352}}

# %% [markdown]
# <h3>Path text files</h3>
# <b>Brief here. Each Column is described in detail in session (Deep Dive) below</b>
# <p></p>
# Let's look more closely at the path text files and how to process them.
#
# The [GitHub README](https://github.com/location-competition/indoor-location-competition-20) provides more information about the text file format:
#
# > The first column is Unix Time in millisecond. In specific, we use SensorEvent.timestamp for sensor data and system time for WiFi and Bluetooth scans.
# >
# >The second column is the data type (ten in total).
# >
# >TYPE_ACCELEROMETER
# >
# >TYPE_MAGNETIC_FIELD
# >
# >TYPE_GYROSCOPE
# >
# >TYPE_ROTATION_VECTOR
# >
# >TYPE_MAGNETIC_FIELD_UNCALIBRATED
# >TYPE_GYROSCOPE_UNCALIBRATED
# >
# >TYPE_ACCELEROMETER_UNCALIBRATED
# >
# >TYPE_WIFI
# >
# >TYPE_BEACON
# >
# >TYPE_WAYPOINT: ground truth location labeled by the surveyor
# >
# >Data values start from the third column.
# >
# >Column 3-5 of TYPE_ACCELEROMETER、TYPE_ACCELEROMETER、TYPE_GYROSCOPE、TYPE_ROTATION_VECTOR are SensorEvent.values[0-2] from the callback function onSensorChanged(). Column 6 is SensorEvent.accuracy.
# >
# >Column 3-8 of TYPE_ACCELEROMETER_UNCALIBRATED、TYPE_GYROSCOPE_UNCALIBRATED、TYPE_MAGNETIC_FIELD_UNCALIBRATED are SensorEvent.values[0-5] from the callback function onSensorChanged(). Column 9 is SensorEvent.accuracy.

# %% [markdown]
# <b>Let's Explore Text File</b>

# %%
example_floor_path = example_site_path/'B1'
example_txt_path = example_floor_path/os.listdir(example_floor_path)[0]
with open(example_txt_path) as example_txt:
    data = example_txt.read()
    example_txt.close()

##################### In comment because Large Output Data ########################
# print(data)

# %% [markdown]
# <h2><center>Deep Dive into EDA</h2>

# %% [markdown]
# <center><img src ="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRSq7tFWVYNmxhjebh_havbaBkI5UmrewSEKw&usqp=CAU " width = "400" height = "400"/></center>

# %% [markdown]
# <h4>Define some Functions/Tools that we will use for EDA</h4>

# %%
def load_trace_as_dataframe(filepath):
    # Returns trace dataframe sorted by timestamp
    
    names = ['time', 'type'] + [f'col_{i}' for i in range(1, 9)]
    
    trace_df = pd.read_csv(
        filepath, sep='\t', comment='#', header=None, names=names
    )
    
    trace_df.sort_values(by='time', inplace=True)
    trace_df.reset_index(drop=True, inplace=True)
    return trace_df

# %%
def extract_feature_df(trace_df, 
                       feature_name, 
                       col_names=('x', 'y', 'z', 'accuracy')):
    
    
#     Extracts feature dataframe from trace dataframe by feature name.
    
#     Suitable for features: 
#     ----------------------
#         TYPE_WAYPOINT, if set col_names=('x', 'y'),
#         TYPE_ACCELEROMETER,
#         TYPE_GYROSCOPE,
#         TYPE_MAGNETIC_FIELD, 
#         TYPE_ROTATION_VECTOR,
        
#         TYPE_ACCELEROMETER_UNCALIBRATED, 
#                     if set col_names=('x', 'y', 'z', 'x_2', 'y_2', 'z_2', 'accuracy'),
                    
#         TYPE_GYROSCOPE_UNCALIBRATED, 
#                     if set col_names=('x', 'y', 'z', 'x_2', 'y_2', 'z_2', 'accuracy'),
                    
#         TYPE_MAGNETIC_FIELD_UNCALIBRATED, 
#                     if set col_names=('x', 'y', 'z', 'x_2', 'y_2', 'z_2', 'accuracy')
    
    
    feature_df = trace_df[trace_df['type'] == feature_name].copy()
    for i, col in enumerate(col_names, start=1):
        feature_df[col] = feature_df[f'col_{i}'].astype('float64')
        
    feature_df.drop(columns=[f'col_{i}' for i in range(1, 9)], inplace=True)
    feature_df.drop(columns=['type'], inplace=True)
    feature_df.reset_index(drop=True, inplace=True)
    
    return feature_df

# %%
def load_points(filepath):
    # Takes the path to the trace file.
    # Returns pandas dataframe which consists of device locations 
    # as x and y coordinates (values from TYPE_WAYPOINT) and their timestamps.
    
    trace_df = load_trace_as_dataframe(filepath)
    points_df = extract_feature_df(
        trace_df, 'TYPE_WAYPOINT', col_names=('x', 'y')
    )
    
    return points_df

# %%
def visualize_many_traces_on_the_map(traces_dataframes, map_image, width, height, 
                                     traces_filenames=None, 
                                     figsize=None):
    

#     Draws traces on the floor map.
    
#     Parameters
#     ----------
#         traces_dataframes: list of pandas DataFrames
#             Each DataFrame should consist of device locations as x and y 
#             coordinates and their timestamps.

#         map_image : numpy.array
#             Image of floor map.

#         width : float,
#             Width of floor. Should be taken from floor_info.json

#         height : float, 
#             Height of floor. Should be taken from floor_info.json

#         traces_filenames : list of strings, optional, default: None
#             List of filenames. Used to display the legend. 
#             There will be no legend if you pass traces_filenames=None

#         figsize : (float, float), optional, default: None
#             Size of the result image in terms of matplotlib.
    

    
    fig = plt.figure(figsize=figsize)
    ax = plt.subplot(111)

    plt.imshow(map_image, extent=[0, width, 0, height])

    if traces_filenames:
        
        for filename, points in zip(traces_filenames, traces_dataframes):
            plt.scatter(points['x'], points['y'], label=filename)
            plt.plot(points['x'], points['y'])
            
        ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
    else:
        for points in traces_dataframes:
            plt.scatter(points['x'], points['y'])
            plt.plot(points['x'], points['y'])


    plt.show()

# %%
def visualize_single_trace_on_the_map(points_df, map_image, width, height, 
                                      scaling_coef=0.3, figsize=None):
    
    
#     Draws single trace on the floor map.
    
#     Parameters
#     ----------
#         points_df: pandas DataFrame
#             Should consist of device locations as x and y 
#             coordinates and their timestamps.

#         map_image : numpy.array
#             Image of floor map.

#         width : float,
#             Width of floor. Should be taken from floor_info.json

#         height : float, 
#             Height of floor. Should be taken from floor_info.json

#         scaling_coef : float
#             Scaling Coefficient. 

#         figsize : (float, float), optional, default: None
#             Size of the result image in terms of matplotlib.
    
    
    
    fig = plt.figure(figsize=figsize)
    ax = plt.subplot(111)

    plt.imshow(map_image, extent=[0, width, 0, height])
    plt.plot(points_df['x'], points_df['y'], linewidth=5, linestyle='-', color='blue')

    for i in range(len(points_df)):
        ax.text(
            points_df.loc[i, 'x'], points_df.loc[i, 'y'], i, 
            ha="center", size=15, 
            bbox=dict(boxstyle="circle, pad=0.3", 
                      fc="cyan", lw=2)
        )
 
    x_min, x_max = points_df['x'].min(), points_df['x'].max()
    y_min, y_max = points_df['y'].min(), points_df['y'].max()

    ax.set_xlim(x_min - scaling_coef*(x_max - x_min), x_max + scaling_coef*(x_max - x_min))
    ax.set_ylim(y_min - scaling_coef*(y_max - y_min), y_max + scaling_coef*(y_max - y_min))

    plt.show()

# %%
def plot_trace_features(feature_df, timestamps=None, figsize=None):
    

#     Plots the trace features.
    
#     Parameters
#     ----------
#         feature_df : pandas DataFrame
#             Can be exctracted from trace dataframe 
#             using extract_feature_df function.
        
#         timestamps : array-like, optional, default: None
#             Array of timestamps. 
#             Used to mark timestamps on the chart in the form of vertical lines.
#             Pass timestamps=None if you don't want to use this feature.

#         figsize : (float, float), optional, default: None
#             Size of the result image in terms of matplotlib.
    
#     Suitable for features: 
#     ----------------------
#         TYPE_ACCELEROMETER 
#         TYPE_GYROSCOPE 
#         TYPE_MAGNETIC_FIELD 
#         TYPE_ROTATION_VECTOR 
#         TYPE_ACCELEROMETER_UNCALIBRATED 
#         TYPE_GYROSCOPE_UNCALIBRATED 
#         TYPE_MAGNETIC_FIELD_UNCALIBRATED
   
    
    fig = plt.figure(figsize=figsize)
    ax = plt.subplot(111)

    for col in ['x', 'y', 'z']:
        plt.plot(feature_df['time'], feature_df[col], label=col)


    if points_df is not None:
        xmin, xmax, ymin, ymax = plt.axis()

        for i, timestamp in enumerate(timestamps):
            plt.axvline(x=timestamp, c='k', ls='--')

            ax.text(
            timestamp, ymax, i, 
            ha="center", size=15, 
            bbox=dict(boxstyle="circle, pad=0.3", 
                      fc="white", lw=2)
            )
    ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
    plt.show()

# %%
data_path = '/kaggle/input/indoor-location-navigation'
floor = '5a0546857ecc773753327266/F1'
floor_metadata_dir = os.path.join(data_path, 'metadata', floor)
floor_train_dir = os.path.join(data_path, 'train', floor)

# %% [markdown]
# <h4>Loading coordinates of paths points</h4>

# %%
paths = []
for filename in os.listdir(floor_train_dir):
    if '.txt' not in filename:
        continue
    points = load_points(os.path.join(floor_train_dir, filename))
    paths.append((filename, points))

paths = sorted(paths, key=lambda path: len(path[1]), reverse=True)
paths = paths[:20]


traces_dataframes = [trace for filename, trace in paths]
traces_filenames = [filename for filename, trace in paths]

# %% [markdown]
# <h4>Loading floor map and its size</h4>

# %%
MAP_IMAGE = plt.imread(
    os.path.join(floor_metadata_dir, 'floor_image.png')
)

with open(os.path.join(floor_metadata_dir, 'floor_info.json')) as f:
    content = f.read()
    floor_info = json.loads(content)

MAP_HEIGHT = float(floor_info['map_info']['height'])
MAP_WIDTH = float(floor_info['map_info']['width'])
    
floor_info
# Out:
# {'map_info': {'height': 152.3075447409275, 'width': 122.40020010253855}}

# %% [markdown]
# <h4>Visualization of Traces (Paths) on the Floor Map</h4>

# %%
visualize_many_traces_on_the_map(
    traces_dataframes, MAP_IMAGE, MAP_WIDTH, MAP_HEIGHT, 
    traces_filenames=traces_filenames, 
    figsize=(15, 12)
)

# %% [markdown]
# <h4>Features Visualization</h4>
# Let's take a closer look at single trace (path) and its attributes.

# %%
filename='5e15b0171506f2000638fe49.txt'
trace_filepath = os.path.join(floor_train_dir, filename)

trace_df = load_trace_as_dataframe(trace_filepath)
trace_df
# Out:
#                 time                              type  \
# 0      1578478950611                     TYPE_WAYPOINT
# 1      1578478950696                       TYPE_BEACON
# 2      1578478950733               TYPE_MAGNETIC_FIELD
# 3      1578478950733                    TYPE_GYROSCOPE
# 4      1578478950733              TYPE_ROTATION_VECTOR
# ...              ...                               ...
# 28505  1578479005275                    TYPE_GYROSCOPE
# 28506  1578479005275              TYPE_ROTATION_VECTOR
# 28507  1578479005275  TYPE_MAGNETIC_FIELD_UNCALIBRATED
# 28508  1578479005275       TYPE_GYROSCOPE_UNCALIBRATED
# 28509  1578479005275   TYPE_ACCELEROMETER_UNCALIBRATED
#
#                                           col_1  \
# 0                                      35.81434
# 1      d9c573b719a17da4836208fc436f87b5ca1aa877
# 2                                     16.067505
# 3                                   -0.35499573
# 4                                   0.042973697
# ...                                         ...
# 28505                              -0.014633179
# 28506                                0.21967757
# 28507                                 -39.54315
# 28508                               0.024963379
# 28509                                 0.5091095
#
#                                           col_2  \
# 0                                      73.54972
# 1      b6589fc6ab0dc82cf12099d1c2d40ab994e8410c
# 2                                     -35.10437
# 3                                   -0.35671997
# 4                                      0.261133
# ...                                         ...
# 28505                               0.017196655
# 28506                               -0.19740751
# 28507                                 4.8568726
# 28508                              -0.018829346
# 28509                                  4.968689
#
#                                           col_3      col_4      col_5  \
# 0                                           NaN        NaN        NaN
# 1      b6589fc6ab0dc82cf12099d1c2d40ab994e8410c -56.000000 -69.000000
# 2                                    -14.152527   3.000000        NaN
# 3                                   -0.47543335   3.000000        NaN
# 4                                    0.92708725   3.000000        NaN
# ...                                         ...        ...        ...
# 28505                              0.0071258545   3.000000        NaN
# 28506                                 -0.594244   3.000000        NaN
# 28507                                -363.15002  -2.886963   3.192139
# 28508                               -0.01637268  -0.009933   0.003937
# 28509                                  7.712509   0.000000   0.000000
#
#             col_6                                     col_7         col_8
# 0             NaN                                       NaN           NaN
# 1        4.609608  bbb0c3915a9608e1ae4a5029ce5ff32b422f4e52  1.578479e+12
# 2             NaN                                       NaN           NaN
# 3             NaN                                       NaN           NaN
# 4             NaN                                       NaN           NaN
# ...           ...                                       ...           ...
# 28505         NaN                                       NaN           NaN
# 28506         NaN                                       NaN           NaN
# 28507 -339.547730                                         3           NaN
# 28508   -0.006989                                         3           NaN
# 28509    0.000000                                         3           NaN
#
# [28510 rows x 10 columns]

# %% [markdown]
# Here is a table of the attributes we need to deal with in this competition.
#
# As you can see it contains feature names and its params. We will describe some of these features in more detail below.
#
# Each feature can be extracted from trace as dataframe with params as columns. For this we are using function `extract_feature_df` which is suitable for all features except TYPE_WIFI and TYPE_BEACON.
#
# The table is taken from [competition's official github repo](https://github.com/location-competition/indoor-location-competition-20).

# %% [markdown]
# | Feature                           | Values |       |        |        |                   |        |           |                                   |
# |:----------------------------------|:------:|:-----:|:------:|:-------|:-----------------:|:------:|:---------:|:---------------------------------:|
# |TYPE_WAYPOINT                      |X axis  |Y axis |       |         |                   |        |           |                                   |
# |TYPE_ACCELEROMETER                 |X axis  |Y axis |Z axis |accuracy |                   |        |           |                                   |
# |TYPE_GYROSCOPE                     |X axis  |Y axis |Z axis |accuracy |                   |        |           |                                   |
# |TYPE_MAGNETIC_FIELD                |X axis  |Y axis |Z axis |accuracy |                   |        |           |                                   |
# |TYPE_ROTATION_VECTOR               |X axis  |Y axis |Z axis |accuracy |                   |        |           |                                   |
# |TYPE_ACCELEROMETER_UNCALIBRATED    |X axis  |Y axis |Z axis |X axis   |Y axis             |Z axis  |accuracy   |                                   |
# |TYPE_GYROSCOPE_UNCALIBRATED        |X axis  |Y axis |Z axis |X axis   |Y axis             |Z axis  |accuracy   |                                   |
# |TYPE_MAGNETIC_FIELD_UNCALIBRATED   |X axis  |Y axis |Z axis |X axis   |Y axis             |Z axis  |accuracy   |                                   |
# |TYPE_WIFI                          |ssid    |bssid  |RSSI   |frequency|last seen timestamp|        |           |                                   |
# |TYPE_BEACON                        |UUID    |MajorID|MinorID|Tx Power |RSSI               |Distance|MAC Address|same with Unix time, padding data  |
# ​

# %% [markdown]
# <b>TYPE_WAYPOINT</b>

# %%
points_df = extract_feature_df(trace_df, 'TYPE_WAYPOINT', col_names=('x', 'y'))
points_df.head()
# Out:
#             time          x          y
# 0  1578478950611  35.814340  73.549720
# 1  1578478957435  32.286610  69.241295
# 2  1578478963201  28.685219  66.200134
# 3  1578478967786  25.548065  63.200860
# 4  1578478972835  22.653585  59.197983

# %%
visualize_single_trace_on_the_map(
    points_df, MAP_IMAGE, MAP_WIDTH, MAP_HEIGHT, figsize=(10, 8)
)

# %% [markdown]
# <b>TYPE_ACCELEROMETER</b>

# %%
acc_df = extract_feature_df(trace_df, 'TYPE_ACCELEROMETER')
acc_df.head()
# Out:
#             time         x         y         z  accuracy
# 0  1578478950733 -0.334244  4.325256  7.615540       2.0
# 1  1578478950753 -0.505417  4.041534  7.962707       2.0
# 2  1578478950773 -0.967499  4.353989  8.285324       2.0
# 3  1578478950793 -1.474487  4.670013  8.069840       2.0
# 4  1578478950813 -1.438568  4.775970  7.264191       2.0

# %%
sns.pairplot(acc_df[['x', 'y', 'z']])
plt.show()

# %% [markdown]
# <b>TYPE_GYROSCOPE</b>

# %%
gyro_df = extract_feature_df(trace_df, 'TYPE_GYROSCOPE')
gyro_df.head()
# Out:
#             time         x         y         z  accuracy
# 0  1578478950733 -0.354996 -0.356720 -0.475433       3.0
# 1  1578478950753 -0.444473 -0.373230 -0.527634       3.0
# 2  1578478950773 -0.435944 -0.342331 -0.560654       3.0
# 3  1578478950793 -0.312378 -0.176163 -0.486084       3.0
# 4  1578478950813 -0.181351  0.065125 -0.377426       3.0

# %% [markdown]
# <b>TYPE_MAGNETIC_FIELD</b>

# %%
magn_df = extract_feature_df(trace_df, 'TYPE_MAGNETIC_FIELD')
magn_df.head()
# Out:
#             time          x          y          z  accuracy
# 0  1578478950733  16.067505 -35.104370 -14.152527       3.0
# 1  1578478950753  15.374756 -37.185670 -14.826965       3.0
# 2  1578478950773  16.067505 -35.798645 -16.177368       3.0
# 3  1578478950793  18.148804 -36.491394 -16.177368       3.0
# 4  1578478950813  16.067505 -35.104370 -17.527771       3.0

# %% [markdown]
# <b>TYPE_ROTATION_VECTOR</b>

# %%
rot_df = extract_feature_df(trace_df, 'TYPE_ROTATION_VECTOR')
rot_df.head()
# Out:
#             time         x         y         z  accuracy
# 0  1578478950733  0.042974  0.261133  0.927087       3.0
# 1  1578478950753  0.042974  0.261133  0.927087       3.0
# 2  1578478950773  0.036968  0.246351  0.929708       3.0
# 3  1578478950793  0.029699  0.247163  0.929281       3.0
# 4  1578478950813  0.029699  0.247163  0.929281       3.0

# %%
sns.pairplot(rot_df[['x', 'y', 'z']])
plt.show()

# %% [markdown]
# <h2><center>Baseline Model 1</h2></center>
# <center><img src ="https://lightgbm.readthedocs.io/en/latest/_images/LightGBM_logo_black_text.svg " width = "400" height = "400"/></center>

# %%
import numpy as np
import pandas as pd
import scipy.stats as stats
from pathlib import Path
import glob

from sklearn.model_selection import KFold
import lightgbm as lgb

import psutil
import random
import os
import time
import sys
import math
from contextlib import contextmanager

# %%
N_SPLITS = 20
SEED = 1234

# %% [markdown]
# Get file path from kaggle

# %%
LOG_PATH = Path("./log/")
LOG_PATH.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# Some utility code
#
# 1. A timer
# 2. A seed setter
# 3. A intermediate metric finder
# 4. A score logger

# %%
@contextmanager
def timer(name: str):
    t0 = time.time()
    p = psutil.Process(os.getpid())
    m0 = p.memory_info()[0] / 2. ** 30
    try:
        yield
    finally:
        m1 = p.memory_info()[0] / 2. ** 30
        delta = m1 - m0
        sign = '+' if delta >= 0 else '-'
        delta = math.fabs(delta)
        print(f"[{m1:.1f}GB({sign}{delta:.1f}GB): {time.time() - t0:.3f}sec] {name}", file=sys.stderr)


def set_seed(seed=1234):
    random.seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)
    np.random.seed(seed)

    
def comp_metric(xhat, yhat, fhat, x, y, f):
    intermediate = np.sqrt(np.power(xhat-x, 2) + np.power(yhat-y, 2)) + 15 * np.abs(fhat-f)
    return intermediate.sum()/xhat.shape[0]


def score_log(df: pd.DataFrame, num_files: int, nam_file: str, data_shape: tuple, n_fold: int, seed: int, mpe: float):
    score_dict = {'n_files': num_files, 'file_name': nam_file, 'shape': data_shape, 'fold': n_fold, 'seed': seed, 'score': mpe}
    # noinspection PyTypeChecker
    df = pd.concat([df, pd.DataFrame.from_dict([score_dict])])
    df.to_csv(LOG_PATH / f"log_score.csv", index=False)
    return df

# %% [markdown]
# Get all the data in our nb env

# %%
set_seed(SEED)
feature_dir = "../input/indoor-navigation-and-location-wifi-features"
train_files = sorted(glob.glob(os.path.join(feature_dir, '*_train.csv')))
test_files = sorted(glob.glob(os.path.join(feature_dir, '*_test.csv')))
subm = pd.read_csv('../input/indoor-location-navigation/sample_submission.csv', index_col=0)

# %% [markdown]
# Create some tuned paratmeters for the LGB ( These will be tweaked to get the best performance)

# %%
lgb_params = {'objective': 'root_mean_squared_error',
              'boosting_type': 'gbdt',
              'n_estimators': 50000,
              'learning_rate': 0.1,
              'num_leaves': 90,
              'colsample_bytree': 0.4,
              'subsample': 0.6,
              'subsample_freq': 2,
              'bagging_seed': SEED,
              'reg_alpha': 8,
              'reg_lambda': 2,
              'random_state': SEED,
              'n_jobs': -1
              }

lgb_f_params = {'objective': 'multiclass',
                'boosting_type': 'gbdt',
                'n_estimators': 50000,
                'learning_rate': 0.1,
                'num_leaves': 90,
                'colsample_bytree': 0.4,
                'subsample': 0.6,
                'subsample_freq': 2,
                'bagging_seed': SEED,
                'reg_alpha': 10,
                'reg_lambda': 2,
                'random_state': SEED,
                'n_jobs': -1
                }

# %% [markdown]
# Splitting the data into train and validation and passed them through LGBm and then ssaving the predicitions into pred

# %% [markdown]
# <b>Below is Light GBM code. Commented because very large output.</b>

# %%
score_df = pd.DataFrame()
oof = list()
predictions = list()
for n_files, file in enumerate(train_files):
    data = pd.read_csv(file, index_col=0)
    test_data = pd.read_csv(test_files[n_files], index_col=0)

    oof_x, oof_y, oof_f = np.zeros(data.shape[0]), np.zeros(data.shape[0]), np.zeros(data.shape[0])
    preds_x, preds_y = 0, 0
    preds_f_arr = np.zeros((test_data.shape[0], N_SPLITS))

    kf = KFold(n_splits=N_SPLITS, shuffle=True, random_state=SEED)
    for fold, (trn_idx, val_idx) in enumerate(kf.split(data.iloc[:, :-4])):
        X_train = data.iloc[trn_idx, :-4]
        y_trainx = data.iloc[trn_idx, -4]
        y_trainy = data.iloc[trn_idx, -3]
        y_trainf = data.iloc[trn_idx, -2]

        X_valid = data.iloc[val_idx, :-4]
        y_validx = data.iloc[val_idx, -4]
        y_validy = data.iloc[val_idx, -3]
        y_validf = data.iloc[val_idx, -2]

        modelx = lgb.LGBMRegressor(**lgb_params)
        with timer("fit X"):
            modelx.fit(X_train, y_trainx,
                       eval_set=[(X_valid, y_validx)],
                       eval_metric='rmse',
                       verbose=True,
                       early_stopping_rounds=5
                       )

        modely = lgb.LGBMRegressor(**lgb_params)
        with timer("fit Y"):
            modely.fit(X_train, y_trainy,
                       eval_set=[(X_valid, y_validy)],
                       eval_metric='rmse',
                       verbose=True,
                       early_stopping_rounds=5
                       )
        modelf = lgb.LGBMClassifier(**lgb_f_params)
        with timer("fit F"):
            modelf.fit(X_train, y_trainf,
                       eval_set=[(X_valid, y_validf)],
                       eval_metric='multi_logloss',
                       verbose=True,
                       early_stopping_rounds=5
                       )

        oof_x[val_idx] = modelx.predict(X_valid)
        oof_y[val_idx] = modely.predict(X_valid)
        oof_f[val_idx] = modelf.predict(X_valid).astype(int)

        preds_x += modelx.predict(test_data.iloc[:, :-1]) / N_SPLITS
        preds_y += modely.predict(test_data.iloc[:, :-1]) / N_SPLITS
        preds_f_arr[:, fold] = modelf.predict(test_data.iloc[:, :-1]).astype(int)

        score = comp_metric(oof_x[val_idx], oof_y[val_idx], oof_f[val_idx],
                            y_validx.to_numpy(), y_validy.to_numpy(), y_validf.to_numpy())
        print(f"fold {fold}: mean position error {score}")
        score_df = score_log(score_df, n_files, os.path.basename(file), data.shape, fold, SEED, score)

    print("*+"*40)
    print(f"file #{n_files}, shape={data.shape}, name={os.path.basename(file)}")
    score = comp_metric(oof_x, oof_y, oof_f,
                        data.iloc[:, -4].to_numpy(), data.iloc[:, -3].to_numpy(), data.iloc[:, -2].to_numpy())
    oof.append(score)
    print(f"mean position error {score}")
    print("*+"*40)
    score_df = score_log(score_df, n_files, os.path.basename(file), data.shape, 999, SEED, score)

    preds_f_mode = stats.mode(preds_f_arr, axis=1)
    preds_f = preds_f_mode[0].astype(int).reshape(-1)
    test_preds = pd.DataFrame(np.stack((preds_f, preds_x, preds_y))).T
    test_preds.columns = subm.columns
    test_preds.index = test_data["site_path_timestamp"]
    test_preds["floor"] = test_preds["floor"].astype(int)
    predictions.append(test_preds)
# Out:
# [1]	valid_0's rmse: 50.9071
# Training until validation scores don't improve for 5 rounds
# [2]	valid_0's rmse: 46.2608
# [3]	valid_0's rmse: 42.0384
# [4]	valid_0's rmse: 38.2657
# [5]	valid_0's rmse: 34.7838
# [6]	valid_0's rmse: 31.6143
# [7]	valid_0's rmse: 28.8646
# [8]	valid_0's rmse: 26.3842
# [9]	valid_0's rmse: 24.1493
# [10]	valid_0's rmse: 22.0908
# [11]	valid_0's rmse: 20.2753
# [12]	valid_0's rmse: 18.5866
# [13]	valid_0's rmse: 17.1225
# [14]	valid_0's rmse: 15.7946
# [15]	valid_0's rmse: 14.609
# [16]	valid_0's rmse: 13.535
# [17]	valid_0's rmse: 12.57
# [18]	valid_0's rmse: 11.6816
# [19]	valid_0's rmse: 10.9126
# [20]	valid_0's rmse: 10.2434
# [21]	valid_0's rmse: 9.61252
# [22]	valid_0's rmse: 9.06317
# [23]	valid_0's rmse: 8.54478
# [24]	valid_0's rmse: 8.10276
# [25]	valid_0's rmse: 7.70468
# [26]	valid_0's rmse: 7.35398
# [27]	valid_0's rmse: 7.05661
# [28]	valid_0's rmse: 6.76872
# [29]	valid_0's rmse: 6.52522
# [30]	valid_0's rmse: 6.32618
# [31]	valid_0's rmse: 6.12389
# [32]	valid_0's rmse: 5.94732
# [33]	valid_0's rmse: 5.79577
# [34]	valid_0's rmse: 5.64516
# [35]	valid_0's rmse: 5.50771
# [36]	valid_0's rmse: 5.40086
# [37]	valid_0's rmse: 5.31802
# [38]	valid_0's rmse: 5.24815
# [39]	valid_0's rmse: 5.17852
# [40]	valid_0's rmse: 5.1119
# [41]	valid_0's rmse: 5.04472
# [42]	valid_0's rmse: 4.97273
# [43]	valid_0's rmse: 4.91673
# [44]	valid_0's rmse: 4.86139
# [45]	valid_0's rmse: 4.81081
# [46]	valid_0's rmse: 4.76936
# [47]	valid_0's rmse: 4.72645
# [48]	valid_0's rmse: 4.69419
# [49]	valid_0's rmse: 4.66377
# [50]	valid_0's rmse: 4.618
# [51]	valid_0's rmse: 4.58895
# [52]	valid_0's rmse: 4.56356
# [53]	valid_0's rmse: 4.52626
# [54]	valid_0's rmse: 4.49928
# [55]	valid_0's rmse: 4.47396
# [56]	valid_0's rmse: 4.44943
# [57]	valid_0's rmse: 4.43532
# [58]	valid_0's rmse: 4.41891
# [59]	valid_0's rmse: 4.39716
# [60]	valid_0's rmse: 4.386
# [61]	valid_0's rmse: 4.36406
# [62]	valid_0's rmse: 4.34616
# [63]	valid_0's rmse: 4.3308
# [64]	valid_0's rmse: 4.32094
# [65]	valid_0's rmse: 4.29688
# [66]	valid_0's rmse: 4.2902
# [67]	valid_0's rmse: 4.28476
# [68]	valid_0's rmse: 4.27421
# [69]	valid_0's rmse: 4.25203
# [70]	valid_0's rmse: 4.24399
# [71]	valid_0's rmse: 4.23134
# [72]	valid_0's rmse: 4.21471
# [73]	valid_0's rmse: 4.20549
# [74]	valid_0's rmse: 4.19103
# [75]	valid_0's rmse: 4.17642
# [76]	valid_0's rmse: 4.16361
# [77]	valid_0's rmse: 4.15148
# [78]	valid_0's rmse: 4.14085
# [79]	valid_0's rmse: 4.13031
# [80]	valid_0's rmse: 4.12228
# [81]	valid_0's rmse: 4.11083
# [82]	valid_0's rmse: 4.10177
# [83]	valid_0's rmse: 4.09342
# [84]	valid_0's rmse: 4.09538
# [85]	valid_0's rmse: 4.0899
# [86]	valid_0's rmse: 4.08139
# [87]	valid_0's rmse: 4.06992
# [88]	valid_0's rmse: 4.06383
# [89]	valid_0's rmse: 4.05123
# [90]	valid_0's rmse: 4.04721
# [91]	valid_0's rmse: 4.03922
# [92]	valid_0's rmse: 4.02849
# [93]	valid_0's rmse: 4.03088
# [94]	valid_0's rmse: 4.02483
# [95]	valid_0's rmse: 4.01593
# [96]	valid_0's rmse: 4.01013
# [97]	valid_0's rmse: 4.00168
# [98]	valid_0's rmse: 3.98978
# [99]	valid_0's rmse: 3.98533
# [100]	valid_0's rmse: 3.97908
# [101]	valid_0's rmse: 3.97592
# [102]	valid_0's rmse: 3.97044
# [103]	valid_0's rmse: 3.96457
# [104]	valid_0's rmse: 3.96086
# [105]	valid_0's rmse: 3.94915
# [106]	valid_0's rmse: 3.94096
# [107]	valid_0's rmse: 3.94269
# [108]	valid_0's rmse: 3.94144
# [109]	valid_0's rmse: 3.93797
# [110]	valid_0's rmse: 3.93524
# [111]	valid_0's rmse: 3.92523
# [112]	valid_0's rmse: 3.92068
# [113]	valid_0's rmse: 3.91173
# [114]	valid_0's rmse: 3.90538
# [115]	valid_0's rmse: 3.89617
# [116]	valid_0's rmse: 3.88943
# [117]	valid_0's rmse: 3.88322
# [118]	valid_0's rmse: 3.87712
# [119]	valid_0's rmse: 3.87532
# [120]	valid_0's rmse: 3.87263
# [121]	valid_0's rmse: 3.87056
# [122]	valid_0's rmse: 3.86187
# [123]	valid_0's rmse: 3.85772
# [124]	valid_0's rmse: 3.84969
# [125]	valid_0's rmse: 3.85072
# [126]	valid_0's rmse: 3.84907
# [127]	valid_0's rmse: 3.84087
# [128]	valid_0's rmse: 3.83577
# [129]	valid_0's rmse: 3.82662
# [130]	valid_0's rmse: 3.82025
# [131]	valid_0's rmse: 3.81699
# [132]	valid_0's rmse: 3.81007
# [133]	valid_0's rmse: 3.80681
# [134]	valid_0's rmse: 3.8005
# [135]	valid_0's rmse: 3.79604
# [136]	valid_0's rmse: 3.79218
# [137]	valid_0's rmse: 3.78617
# [138]	valid_0's rmse: 3.78632
# [139]	valid_0's rmse: 3.77564
# [140]	valid_0's rmse: 3.77691
# [141]	valid_0's rmse: 3.77278
# [142]	valid_0's rmse: 3.77185
# [143]	valid_0's rmse: 3.76932
# [144]	valid_0's rmse: 3.76619
# [145]	valid_0's rmse: 3.76213
# [146]	valid_0's rmse: 3.75862
# [147]	valid_0's rmse: 3.75714
# [148]	valid_0's rmse: 3.75794
# [149]	valid_0's rmse: 3.75357
# [150]	valid_0's rmse: 3.75281
# [151]	valid_0's rmse: 3.75075
# [152]	valid_0's rmse: 3.74526
# [153]	valid_0's rmse: 3.74187
# [154]	valid_0's rmse: 3.73598
# [155]	valid_0's rmse: 3.7372
# [156]	valid_0's rmse: 3.73681
# [157]	valid_0's rmse: 3.73366
# [158]	valid_0's rmse: 3.72867
# [159]	valid_0's rmse: 3.71997
# [160]	valid_0's rmse: 3.71969
# [161]	valid_0's rmse: 3.71533
# [162]	valid_0's rmse: 3.71454
# [163]	valid_0's rmse: 3.71192
# [164]	valid_0's rmse: 3.70969
# [165]	valid_0's rmse: 3.70614
# [166]	valid_0's rmse: 3.70207
# [167]	valid_0's rmse: 3.69888
# [168]	valid_0's rmse: 3.69788
# [169]	valid_0's rmse: 3.69311
# [170]	valid_0's rmse: 3.69162
# [171]	valid_0's rmse: 3.68961
# [172]	valid_0's rmse: 3.68877
# [173]	valid_0's rmse: 3.68986
# [174]	valid_0's rmse: 3.68844
# [175]	valid_0's rmse: 3.6871
# [176]	valid_0's rmse: 3.68629
# [177]	valid_0's rmse: 3.68638
# [178]	valid_0's rmse: 3.68505
# [179]	valid_0's rmse: 3.67931
# [180]	valid_0's rmse: 3.67562
# [181]	valid_0's rmse: 3.67411
# [182]	valid_0's rmse: 3.67387
# [183]	valid_0's rmse: 3.66767
# [184]	valid_0's rmse: 3.66657
# [185]	valid_0's rmse: 3.6628
# [186]	valid_0's rmse: 3.66308
# [187]	valid_0's rmse: 3.66277
# [188]	valid_0's rmse: 3.66188
# [189]	valid_0's rmse: 3.65647
# [190]	valid_0's rmse: 3.6581
# [191]	valid_0's rmse: 3.65475
# [192]	valid_0's rmse: 3.65609
# [193]	valid_0's rmse: 3.65474
# [194]	valid_0's rmse: 3.65337
# [195]	valid_0's rmse: 3.65228
# [196]	valid_0's rmse: 3.6519
# [197]	valid_0's rmse: 3.64937
# [198]	valid_0's rmse: 3.64795
# [199]	valid_0's rmse: 3.64717
# [200]	valid_0's rmse: 3.64674
# [201]	valid_0's rmse: 3.64635
# [202]	valid_0's rmse: 3.64415
# [203]	valid_0's rmse: 3.64301
# [204]	valid_0's rmse: 3.63898
# [205]	valid_0's rmse: 3.63707
# [206]	valid_0's rmse: 3.6365
# [207]	valid_0's rmse: 3.63655
# [208]	valid_0's rmse: 3.63715
# [209]	valid_0's rmse: 3.63422
# [210]	valid_0's rmse: 3.63158
# [211]	valid_0's rmse: 3.62488
# [212]	valid_0's rmse: 3.62302
# [213]	valid_0's rmse: 3.62063
# [214]	valid_0's rmse: 3.62145
# [215]	valid_0's rmse: 3.61923
# [216]	valid_0's rmse: 3.61757
# [217]	valid_0's rmse: 3.6144
# [218]	valid_0's rmse: 3.61456
# [219]	valid_0's rmse: 3.6142
# [220]	valid_0's rmse: 3.61315
# [221]	valid_0's rmse: 3.61087
# [222]	valid_0's rmse: 3.60804
# [223]	valid_0's rmse: 3.60645
# [224]	valid_0's rmse: 3.60661
# [225]	valid_0's rmse: 3.60174
# [226]	valid_0's rmse: 3.60055
# [227]	valid_0's rmse: 3.60025
# [228]	valid_0's rmse: 3.59495
# [229]	valid_0's rmse: 3.59048
# [230]	valid_0's rmse: 3.58712
# [231]	valid_0's rmse: 3.58639
# [232]	valid_0's rmse: 3.58263
# [233]	valid_0's rmse: 3.58118
# [234]	valid_0's rmse: 3.5823
# [235]	valid_0's rmse: 3.58525
# [236]	valid_0's rmse: 3.58267
# [237]	valid_0's rmse: 3.57965
# [238]	valid_0's rmse: 3.57865
# [239]	valid_0's rmse: 3.57966
# [240]	valid_0's rmse: 3.58055
# [241]	valid_0's rmse: 3.58162
# [242]	valid_0's rmse: 3.58228
# [243]	valid_0's rmse: 3.58192
# Early stopping, best iteration is:
# [238]	valid_0's rmse: 3.57865
# [1.6GB(+0.4GB): 22.291sec] fit X
# [1]	valid_0's rmse: 38.4241
# Training until validation scores don't improve for 5 rounds
# [2]	valid_0's rmse: 34.7394
# [3]	valid_0's rmse: 31.3889
# [4]	valid_0's rmse: 28.394
# [5]	valid_0's rmse: 25.7125
# [6]	valid_0's rmse: 23.322
# [7]	valid_0's rmse: 21.151
# [8]	valid_0's rmse: 19.2235
# [9]	valid_0's rmse: 17.4676
# [10]	valid_0's rmse: 15.8571
# [11]	valid_0's rmse: 14.3663
# [12]	valid_0's rmse: 13.0669
# [13]	valid_0's rmse: 11.9394
# [14]	valid_0's rmse: 10.905
# [15]	valid_0's rmse: 9.97765
# [16]	valid_0's rmse: 9.15752
# [17]	valid_0's rmse: 8.42265
# [18]	valid_0's rmse: 7.80667
# [19]	valid_0's rmse: 7.23275
# [20]	valid_0's rmse: 6.7326
# [21]	valid_0's rmse: 6.28215
# [22]	valid_0's rmse: 5.91479
# [23]	valid_0's rmse: 5.56048
# [24]	valid_0's rmse: 5.23684
# [25]	valid_0's rmse: 4.97649
# [26]	valid_0's rmse: 4.74651
# [27]	valid_0's rmse: 4.55329
# [28]	valid_0's rmse: 4.37719
# [29]	valid_0's rmse: 4.20912
# [30]	valid_0's rmse: 4.07308
# [31]	valid_0's rmse: 3.94015
# [32]	valid_0's rmse: 3.83459
# [33]	valid_0's rmse: 3.74612
# [34]	valid_0's rmse: 3.66018
# [35]	valid_0's rmse: 3.58664
# [36]	valid_0's rmse: 3.53346
# [37]	valid_0's rmse: 3.48545
# [38]	valid_0's rmse: 3.44799
# [39]	valid_0's rmse: 3.40911
# [40]	valid_0's rmse: 3.36602
# [41]	valid_0's rmse: 3.33649
# [42]	valid_0's rmse: 3.31403
# [43]	valid_0's rmse: 3.28233
# [44]	valid_0's rmse: 3.25186
# [45]	valid_0's rmse: 3.22945
# [46]	valid_0's rmse: 3.21327
# [47]	valid_0's rmse: 3.19373
# [48]	valid_0's rmse: 3.17426
# [49]	valid_0's rmse: 3.15626
# [50]	valid_0's rmse: 3.14083
# [51]	valid_0's rmse: 3.1234
# [52]	valid_0's rmse: 3.1048
# [53]	valid_0's rmse: 3.09377
# [54]	valid_0's rmse: 3.07698
# [55]	valid_0's rmse: 3.06028
# [56]	valid_0's rmse: 3.05134
# [57]	valid_0's rmse: 3.03904
# [58]	valid_0's rmse: 3.02752
# [59]	valid_0's rmse: 3.01632
# [60]	valid_0's rmse: 3.00949
# [61]	valid_0's rmse: 2.99288
# [62]	valid_0's rmse: 2.98457
# [63]	valid_0's rmse: 2.97201
# [64]	valid_0's rmse: 2.96884
# [65]	valid_0's rmse: 2.96367
# [66]	valid_0's rmse: 2.95786
# [67]	valid_0's rmse: 2.95448
# [68]	valid_0's rmse: 2.95284
# [69]	valid_0's rmse: 2.94003
# [70]	valid_0's rmse: 2.93312
# [71]	valid_0's rmse: 2.92832
# [72]	valid_0's rmse: 2.92016
# [73]	valid_0's rmse: 2.90956
# [74]	valid_0's rmse: 2.89915
# [75]	valid_0's rmse: 2.89735
# [76]	valid_0's rmse: 2.89022
# [77]	valid_0's rmse: 2.88567
# [78]	valid_0's rmse: 2.88118
# [79]	valid_0's rmse: 2.87661
# [80]	valid_0's rmse: 2.87683
# [81]	valid_0's rmse: 2.87675
# [82]	valid_0's rmse: 2.87016
# [83]	valid_0's rmse: 2.86621
# [84]	valid_0's rmse: 2.86084
# [85]	valid_0's rmse: 2.8545
# [86]	valid_0's rmse: 2.8519
# [87]	valid_0's rmse: 2.85004
# [88]	valid_0's rmse: 2.84496
# [89]	valid_0's rmse: 2.8465
# [90]	valid_0's rmse: 2.84518
# [91]	valid_0's rmse: 2.84218
# [92]	valid_0's rmse: 2.83871
# [93]	valid_0's rmse: 2.83627
# [94]	valid_0's rmse: 2.83839
# [95]	valid_0's rmse: 2.83858
# [96]	valid_0's rmse: 2.83818
# [97]	valid_0's rmse: 2.83613
# [98]	valid_0's rmse: 2.83347
# [99]	valid_0's rmse: 2.82845
# [100]	valid_0's rmse: 2.82431
# [101]	valid_0's rmse: 2.82067
# [102]	valid_0's rmse: 2.81914
# [103]	valid_0's rmse: 2.81353
# [104]	valid_0's rmse: 2.8122
# [105]	valid_0's rmse: 2.81331
# [106]	valid_0's rmse: 2.80904
# [107]	valid_0's rmse: 2.81
# [108]	valid_0's rmse: 2.80712
# [109]	valid_0's rmse: 2.80243
# [110]	valid_0's rmse: 2.79943
# [111]	valid_0's rmse: 2.7954
# [112]	valid_0's rmse: 2.79366
# [113]	valid_0's rmse: 2.79279
# [114]	valid_0's rmse: 2.78799
# [115]	valid_0's rmse: 2.78468
# [116]	valid_0's rmse: 2.78066
# [117]	valid_0's rmse: 2.77706
# [118]	valid_0's rmse: 2.77049
# [119]	valid_0's rmse: 2.76869
# [120]	valid_0's rmse: 2.76949
# [121]	valid_0's rmse: 2.765
# [122]	valid_0's rmse: 2.75936
# [123]	valid_0's rmse: 2.75843
# [124]	valid_0's rmse: 2.75632
# [125]	valid_0's rmse: 2.75421
# [126]	valid_0's rmse: 2.75114
# [127]	valid_0's rmse: 2.75126
# [128]	valid_0's rmse: 2.7576
# [129]	valid_0's rmse: 2.75338
# [130]	valid_0's rmse: 2.75329
# [131]	valid_0's rmse: 2.74913
# [132]	valid_0's rmse: 2.74664
# [133]	valid_0's rmse: 2.73957
# [134]	valid_0's rmse: 2.73698
# [135]	valid_0's rmse: 2.73276
# [136]	valid_0's rmse: 2.73252
# [137]	valid_0's rmse: 2.72777
# [138]	valid_0's rmse: 2.72648
# [139]	valid_0's rmse: 2.72669
# [140]	valid_0's rmse: 2.72557
# [141]	valid_0's rmse: 2.725
# [142]	valid_0's rmse: 2.7239
# [143]	valid_0's rmse: 2.72386
# [144]	valid_0's rmse: 2.72403
# [145]	valid_0's rmse: 2.72141
# [146]	valid_0's rmse: 2.72058
# [147]	valid_0's rmse: 2.7184
# [148]	valid_0's rmse: 2.71799
# [149]	valid_0's rmse: 2.7211
# [150]	valid_0's rmse: 2.71795
# [151]	valid_0's rmse: 2.71513
# [152]	valid_0's rmse: 2.71505
# [153]	valid_0's rmse: 2.71537
# [154]	valid_0's rmse: 2.71111
# [155]	valid_0's rmse: 2.70827
# [156]	valid_0's rmse: 2.7041
# [157]	valid_0's rmse: 2.70179
# [158]	valid_0's rmse: 2.69952
# [159]	valid_0's rmse: 2.69804
# [160]	valid_0's rmse: 2.69786
# [161]	valid_0's rmse: 2.69731
# [162]	valid_0's rmse: 2.69751
# [163]	valid_0's rmse: 2.69749
# [164]	valid_0's rmse: 2.69841
# [165]	valid_0's rmse: 2.69426
# [166]	valid_0's rmse: 2.69246
# [167]	valid_0's rmse: 2.69219
# [168]	valid_0's rmse: 2.69169
# [169]	valid_0's rmse: 2.68837
# [170]	valid_0's rmse: 2.68671
# [171]	valid_0's rmse: 2.68464
# [172]	valid_0's rmse: 2.68281
# [173]	valid_0's rmse: 2.68171
# [174]	valid_0's rmse: 2.67952
# [175]	valid_0's rmse: 2.67861
# [176]	valid_0's rmse: 2.67628
# [177]	valid_0's rmse: 2.67316
# [178]	valid_0's rmse: 2.67179
# [179]	valid_0's rmse: 2.66933
# [180]	valid_0's rmse: 2.66852
# [181]	valid_0's rmse: 2.66762
# [182]	valid_0's rmse: 2.66965
# [183]	valid_0's rmse: 2.66729
# [184]	valid_0's rmse: 2.66467
# [185]	valid_0's rmse: 2.6644
# [186]	valid_0's rmse: 2.66425
# [187]	valid_0's rmse: 2.66141
# [188]	valid_0's rmse: 2.66145
# [189]	valid_0's rmse: 2.6598
# [190]	valid_0's rmse: 2.65896
# [191]	valid_0's rmse: 2.65884
# [192]	valid_0's rmse: 2.65828
# [193]	valid_0's rmse: 2.65692
# [194]	valid_0's rmse: 2.65639
# [195]	valid_0's rmse: 2.6563
# [196]	valid_0's rmse: 2.65571
# [197]	valid_0's rmse: 2.65297
# [198]	valid_0's rmse: 2.65275
# [199]	valid_0's rmse: 2.64927
# [200]	valid_0's rmse: 2.64565
# [201]	valid_0's rmse: 2.64594
# [202]	valid_0's rmse: 2.64739
# [203]	valid_0's rmse: 2.64511
# [204]	valid_0's rmse: 2.64203
# [205]	valid_0's rmse: 2.64208
# [206]	valid_0's rmse: 2.6392
# [207]	valid_0's rmse: 2.63588
# [208]	valid_0's rmse: 2.63507
# [209]	valid_0's rmse: 2.63555
# [210]	valid_0's rmse: 2.63561
# [211]	valid_0's rmse: 2.63853
# [212]	valid_0's rmse: 2.6386
# [213]	valid_0's rmse: 2.63725
# Early stopping, best iteration is:
# [208]	valid_0's rmse: 2.63507
# [1.7GB(+0.1GB): 20.260sec] fit Y
# [1]	valid_0's multi_logloss: 1.27331
# Training until validation scores don't improve for 5 rounds
# [2]	valid_0's multi_logloss: 1.04882
# [3]	valid_0's multi_logloss: 0.884039
# [4]	valid_0's multi_logloss: 0.754223
# [5]	valid_0's multi_logloss: 0.649356
# [6]	valid_0's multi_logloss: 0.561727
# [7]	valid_0's multi_logloss: 0.486581
# [8]	valid_0's multi_logloss: 0.423839
# [9]	valid_0's multi_logloss: 0.371796
# [10]	valid_0's multi_logloss: 0.326569
# [11]	valid_0's multi_logloss: 0.28831
# [12]	valid_0's multi_logloss: 0.255927
# [13]	valid_0's multi_logloss: 0.227436
# [14]	valid_0's multi_logloss: 0.203629
# [15]	valid_0's multi_logloss: 0.182508
# [16]	valid_0's multi_logloss: 0.164145
# [17]	valid_0's multi_logloss: 0.148437
# [18]	valid_0's multi_logloss: 0.134556
# [19]	valid_0's multi_logloss: 0.122715
# [20]	valid_0's multi_logloss: 0.111581
# [21]	valid_0's multi_logloss: 0.102494
# [22]	valid_0's multi_logloss: 0.0943131
# [23]	valid_0's multi_logloss: 0.0864892
# [24]	valid_0's multi_logloss: 0.0801334
# [25]	valid_0's multi_logloss: 0.0743861
# [26]	valid_0's multi_logloss: 0.0695339
# [27]	valid_0's multi_logloss: 0.0650676
# [28]	valid_0's multi_logloss: 0.0610901
# [29]	valid_0's multi_logloss: 0.0577516
# [30]	valid_0's multi_logloss: 0.0546202
# [31]	valid_0's multi_logloss: 0.0517148
# [32]	valid_0's multi_logloss: 0.049155
# [33]	valid_0's multi_logloss: 0.0470084
# [34]	valid_0's multi_logloss: 0.0453359
# [35]	valid_0's multi_logloss: 0.0437551
# [36]	valid_0's multi_logloss: 0.0422451
# [37]	valid_0's multi_logloss: 0.0408701
# [38]	valid_0's multi_logloss: 0.0396302
# [39]	valid_0's multi_logloss: 0.0384206
# [40]	valid_0's multi_logloss: 0.0373697
# [41]	valid_0's multi_logloss: 0.0365485
# [42]	valid_0's multi_logloss: 0.0357688
# [43]	valid_0's multi_logloss: 0.0347899
# [44]	valid_0's multi_logloss: 0.0340351
# [45]	valid_0's multi_logloss: 0.0336903
# [46]	valid_0's multi_logloss: 0.0334598
# [47]	valid_0's multi_logloss: 0.0330314
# [48]	valid_0's multi_logloss: 0.0327291
# [49]	valid_0's multi_logloss: 0.0323106
# [50]	valid_0's multi_logloss: 0.0320227
# [51]	valid_0's multi_logloss: 0.0316626
# [52]	valid_0's multi_logloss: 0.0316031
# [53]	valid_0's multi_logloss: 0.0313781
# [54]	valid_0's multi_logloss: 0.0311968
# [55]	valid_0's multi_logloss: 0.031054
# [56]	valid_0's multi_logloss: 0.0308816
# [57]	valid_0's multi_logloss: 0.0308232
# [58]	valid_0's multi_logloss: 0.0307719
# [59]	valid_0's multi_logloss: 0.030755
# [60]	valid_0's multi_logloss: 0.0307503
# [61]	valid_0's multi_logloss: 0.0306799
# [62]	valid_0's multi_logloss: 0.0306342
# [63]	valid_0's multi_logloss: 0.0306199
# [64]	valid_0's multi_logloss: 0.0305382
# [65]	valid_0's multi_logloss: 0.0305239
# [66]	valid_0's multi_logloss: 0.0305184
# [67]	valid_0's multi_logloss: 0.0303592
# [68]	valid_0's multi_logloss: 0.0302118
# [69]	valid_0's multi_logloss: 0.0300637
# [70]	valid_0's multi_logloss: 0.0300439
# [71]	valid_0's multi_logloss: 0.02999
# [72]	valid_0's multi_logloss: 0.0299655
# [73]	valid_0's multi_logloss: 0.0299544
# [74]	valid_0's multi_logloss: 0.0299425
# [75]	valid_0's multi_logloss: 0.029904
# [76]	valid_0's multi_logloss: 0.029882
# [77]	valid_0's multi_logloss: 0.0298744
# [78]	valid_0's multi_logloss: 0.0298712
# [79]	valid_0's multi_logloss: 0.0297891
# [80]	valid_0's multi_logloss: 0.0297786
# [81]	valid_0's multi_logloss: 0.0297539
# [82]	valid_0's multi_logloss: 0.0297435
# [83]	valid_0's multi_logloss: 0.0297407
# [84]	valid_0's multi_logloss: 0.0297352
# [85]	valid_0's multi_logloss: 0.0297321
# [86]	valid_0's multi_logloss: 0.0297321
# [87]	valid_0's multi_logloss: 0.0297293
# [88]	valid_0's multi_logloss: 0.0297266
# [89]	valid_0's multi_logloss: 0.0297266
# [90]	valid_0's multi_logloss: 0.0297241
# [91]	valid_0's multi_logloss: 0.0297027
# [92]	valid_0's multi_logloss: 0.0296886
# [93]	valid_0's multi_logloss: 0.0296765
# [94]	valid_0's multi_logloss: 0.0296557
# [95]	valid_0's multi_logloss: 0.0296521
# [96]	valid_0's multi_logloss: 0.0296359
# [97]	valid_0's multi_logloss: 0.0296253
# [98]	valid_0's multi_logloss: 0.0296185
# [99]	valid_0's multi_logloss: 0.0296183
# [100]	valid_0's multi_logloss: 0.0296158
# [101]	valid_0's multi_logloss: 0.0296102
# [102]	valid_0's multi_logloss: 0.0296012
# [103]	valid_0's multi_logloss: 0.0295877
# [104]	valid_0's multi_logloss: 0.0295847
# [105]	valid_0's multi_logloss: 0.0295847
# [106]	valid_0's multi_logloss: 0.0295453
# [107]	valid_0's multi_logloss: 0.0295392
# [108]	valid_0's multi_logloss: 0.0295352
# [109]	valid_0's multi_logloss: 0.0295315
# [110]	valid_0's multi_logloss: 0.029529
# [111]	valid_0's multi_logloss: 0.029529
# [112]	valid_0's multi_logloss: 0.0295267
# [113]	valid_0's multi_logloss: 0.0295267
# [114]	valid_0's multi_logloss: 0.0295213
# [115]	valid_0's multi_logloss: 0.0295104
# [116]	valid_0's multi_logloss: 0.0295104
# [117]	valid_0's multi_logloss: 0.0295084
# [118]	valid_0's multi_logloss: 0.0295084
# [119]	valid_0's multi_logloss: 0.0295084
# [120]	valid_0's multi_logloss: 0.0295069
# [121]	valid_0's multi_logloss: 0.0295067
# [122]	valid_0's multi_logloss: 0.0295062
# [123]	valid_0's multi_logloss: 0.0295034
# [124]	valid_0's multi_logloss: 0.0295034
# [125]	valid_0's multi_logloss: 0.0295008
# [126]	valid_0's multi_logloss: 0.0294987
# [127]	valid_0's multi_logloss: 0.0294961
# [128]	valid_0's multi_logloss: 0.029491
# [129]	valid_0's multi_logloss: 0.0294693
# [130]	valid_0's multi_logloss: 0.0294466
# [131]	valid_0's multi_logloss: 0.029404
# [132]	valid_0's multi_logloss: 0.0293848
# [133]	valid_0's multi_logloss: 0.0293832
# [134]	valid_0's multi_logloss: 0.0293832
# [135]	valid_0's multi_logloss: 0.0293749
# [136]	valid_0's multi_logloss: 0.0293693
# [137]	valid_0's multi_logloss: 0.0293693
# [138]	valid_0's multi_logloss: 0.0293657
# [139]	valid_0's multi_logloss: 0.0293623
# [140]	valid_0's multi_logloss: 0.0293617
# [141]	valid_0's multi_logloss: 0.0293609
# [142]	valid_0's multi_logloss: 0.029362
# [143]	valid_0's multi_logloss: 0.0293625
# [144]	valid_0's multi_logloss: 0.0293366
# [145]	valid_0's multi_logloss: 0.0293127
# [146]	valid_0's multi_logloss: 0.0292835
# [147]	valid_0's multi_logloss: 0.0292835
# [148]	valid_0's multi_logloss: 0.0292816
# [149]	valid_0's multi_logloss: 0.0292721
# [150]	valid_0's multi_logloss: 0.0292687
# [151]	valid_0's multi_logloss: 0.029229
# [152]	valid_0's multi_logloss: 0.029222
# [153]	valid_0's multi_logloss: 0.0292208
# [154]	valid_0's multi_logloss: 0.0292185
# [155]	valid_0's multi_logloss: 0.0292088
# [156]	valid_0's multi_logloss: 0.0291822
# [157]	valid_0's multi_logloss: 0.029182
# [158]	valid_0's multi_logloss: 0.0291819
# [159]	valid_0's multi_logloss: 0.0291819
# [160]	valid_0's multi_logloss: 0.0291818
# [161]	valid_0's multi_logloss: 0.0291816
# [162]	valid_0's multi_logloss: 0.0291816
# [163]	valid_0's multi_logloss: 0.0291816
# [164]	valid_0's multi_logloss: 0.0291816
# [165]	valid_0's multi_logloss: 0.0291816
# [166]	valid_0's multi_logloss: 0.0291816
# [167]	valid_0's multi_logloss: 0.0291527
# [168]	valid_0's multi_logloss: 0.0291529
# [169]	valid_0's multi_logloss: 0.0291517
# [170]	valid_0's multi_logloss: 0.0291505
# [171]	valid_0's multi_logloss: 0.029143
# [172]	valid_0's multi_logloss: 0.029143
# [173]	valid_0's multi_logloss: 0.0291391
# [174]	valid_0's multi_logloss: 0.0291374
# [175]	valid_0's multi_logloss: 0.0291283
# [176]	valid_0's multi_logloss: 0.0291283
# [177]	valid_0's multi_logloss: 0.0291175
# [178]	valid_0's multi_logloss: 0.0291078
# [179]	valid_0's multi_logloss: 0.0291078
# [180]	valid_0's multi_logloss: 0.0291064
# [181]	valid_0's multi_logloss: 0.0291064
# [182]	valid_0's multi_logloss: 0.0291054
# [183]	valid_0's multi_logloss: 0.0291054
# [184]	valid_0's multi_logloss: 0.0291054
# [185]	valid_0's multi_logloss: 0.0291042
# [186]	valid_0's multi_logloss: 0.0291031
# [187]	valid_0's multi_logloss: 0.0291031
# [188]	valid_0's multi_logloss: 0.0291031
# [189]	valid_0's multi_logloss: 0.0291027
# [190]	valid_0's multi_logloss: 0.0291013
# [191]	valid_0's multi_logloss: 0.0291013
# [192]	valid_0's multi_logloss: 0.0291013
# [193]	valid_0's multi_logloss: 0.0291013
# [194]	valid_0's multi_logloss: 0.0291008
# [195]	valid_0's multi_logloss: 0.0291008
# [196]	valid_0's multi_logloss: 0.0291008
# [197]	valid_0's multi_logloss: 0.0291007
# [198]	valid_0's multi_logloss: 0.0290992
# [199]	valid_0's multi_logloss: 0.0290978
# [200]	valid_0's multi_logloss: 0.0290978
# [201]	valid_0's multi_logloss: 0.0290978
# [202]	valid_0's multi_logloss: 0.0290978
# [203]	valid_0's multi_logloss: 0.0290978
# [204]	valid_0's multi_logloss: 0.0290973
# [205]	valid_0's multi_logloss: 0.0290969
# [206]	valid_0's multi_logloss: 0.0290962
# [207]	valid_0's multi_logloss: 0.0290962
# [208]	valid_0's multi_logloss: 0.0290962
# [209]	valid_0's multi_logloss: 0.0290939
# [210]	valid_0's multi_logloss: 0.0290939
# [211]	valid_0's multi_logloss: 0.0290939
# [212]	valid_0's multi_logloss: 0.0290939
# [213]	valid_0's multi_logloss: 0.0290939
# [214]	valid_0's multi_logloss: 0.0290939
# Early stopping, best iteration is:
# [209]	valid_0's multi_logloss: 0.0290939
# [1.8GB(+0.0GB): 38.239sec] fit F
# fold 0: mean position error 3.634173693181935
# [1]	valid_0's rmse: 48.1388
# Training until validation scores don't improve for 5 rounds
# [2]	valid_0's rmse: 43.702
# [3]	valid_0's rmse: 39.7035
# [4]	valid_0's rmse: 36.1342
# [5]	valid_0's rmse: 32.8176
# [6]	valid_0's rmse: 29.9238
# [7]	valid_0's rmse: 27.2628
# [8]	valid_0's rmse: 24.8614
# [9]	valid_0's rmse: 22.7183
# [10]	valid_0's rmse: 20.8348
# [11]	valid_0's rmse: 19.089
# [12]	valid_0's rmse: 17.533
# [13]	valid_0's rmse: 16.131
# [14]	valid_0's rmse: 14.8753
# [15]	valid_0's rmse: 13.7388
# [16]	valid_0's rmse: 12.7026
# [17]	valid_0's rmse: 11.8194
# [18]	valid_0's rmse: 10.9857
# [19]	valid_0's rmse: 10.2261
# [20]	valid_0's rmse: 9.53594
# [21]	valid_0's rmse: 8.94613
# [22]	valid_0's rmse: 8.42249
# [23]	valid_0's rmse: 7.93672
# [24]	valid_0's rmse: 7.50152
# [25]	valid_0's rmse: 7.11068
# [26]	valid_0's rmse: 6.76238
# [27]	valid_0's rmse: 6.44136
# [28]	valid_0's rmse: 6.17362
# [29]	valid_0's rmse: 5.92432
# [30]	valid_0's rmse: 5.72686
# [31]	valid_0's rmse: 5.52641
# [32]	valid_0's rmse: 5.36138
# [33]	valid_0's rmse: 5.2033
# [34]	valid_0's rmse: 5.0526
# [35]	valid_0's rmse: 4.92743
# [36]	valid_0's rmse: 4.79391
# [37]	valid_0's rmse: 4.70182
# [38]	valid_0's rmse: 4.61084
# [39]	valid_0's rmse: 4.52076
# [40]	valid_0's rmse: 4.42881
# [41]	valid_0's rmse: 4.36109
# [42]	valid_0's rmse: 4.29122
# [43]	valid_0's rmse: 4.23927
# [44]	valid_0's rmse: 4.19943
# [45]	valid_0's rmse: 4.15068
# [46]	valid_0's rmse: 4.1172
# [47]	valid_0's rmse: 4.08443
# [48]	valid_0's rmse: 4.04368
# [49]	valid_0's rmse: 4.00932
# [50]	valid_0's rmse: 3.98928
# [51]	valid_0's rmse: 3.97384
# [52]	valid_0's rmse: 3.95242
# [53]	valid_0's rmse: 3.94038
# [54]	valid_0's rmse: 3.92054
# [55]	valid_0's rmse: 3.90023
# [56]	valid_0's rmse: 3.87332
# [57]	valid_0's rmse: 3.8637
# [58]	valid_0's rmse: 3.85031
# [59]	valid_0's rmse: 3.83377
# [60]	valid_0's rmse: 3.8102
# [61]	valid_0's rmse: 3.79687
# [62]	valid_0's rmse: 3.78355
# [63]	valid_0's rmse: 3.77442
# [64]	valid_0's rmse: 3.76434
# [65]	valid_0's rmse: 3.75213
# [66]	valid_0's rmse: 3.72961
# [67]	valid_0's rmse: 3.71762
# [68]	valid_0's rmse: 3.70927
# [69]	valid_0's rmse: 3.69181
# [70]	valid_0's rmse: 3.67553
# [71]	valid_0's rmse: 3.67545
# [72]	valid_0's rmse: 3.66301
# [73]	valid_0's rmse: 3.6602
# [74]	valid_0's rmse: 3.65398
# [75]	valid_0's rmse: 3.64157
# [76]	valid_0's rmse: 3.63883
# [77]	valid_0's rmse: 3.636
# [78]	valid_0's rmse: 3.63176
# [79]	valid_0's rmse: 3.62115
# [80]	valid_0's rmse: 3.6063
# [81]	valid_0's rmse: 3.6005
# [82]	valid_0's rmse: 3.59046
# [83]	valid_0's rmse: 3.58326
# [84]	valid_0's rmse: 3.57663
# [85]	valid_0's rmse: 3.56652
# [86]	valid_0's rmse: 3.56703
# [87]	valid_0's rmse: 3.56829
# [88]	valid_0's rmse: 3.56511
# [89]	valid_0's rmse: 3.55007
# [90]	valid_0's rmse: 3.53508
# [91]	valid_0's rmse: 3.5354
# [92]	valid_0's rmse: 3.52604
# [93]	valid_0's rmse: 3.51958
# [94]	valid_0's rmse: 3.51807
# [95]	valid_0's rmse: 3.51736
# [96]	valid_0's rmse: 3.51301
# [97]	valid_0's rmse: 3.50395
# [98]	valid_0's rmse: 3.50053
# [99]	valid_0's rmse: 3.49933
# [100]	valid_0's rmse: 3.50155
# [101]	valid_0's rmse: 3.49245
# [102]	valid_0's rmse: 3.48989
# [103]	valid_0's rmse: 3.48955
# [104]	valid_0's rmse: 3.48877
# [105]	valid_0's rmse: 3.48297
# [106]	valid_0's rmse: 3.47897
# [107]	valid_0's rmse: 3.47468
# [108]	valid_0's rmse: 3.47724
# [109]	valid_0's rmse: 3.47207
# [110]	valid_0's rmse: 3.46345
# [111]	valid_0's rmse: 3.45618
# [112]	valid_0's rmse: 3.45404
# [113]	valid_0's rmse: 3.45171
# [114]	valid_0's rmse: 3.44971
# [115]	valid_0's rmse: 3.44462
# [116]	valid_0's rmse: 3.44779
# [117]	valid_0's rmse: 3.44656
# [118]	valid_0's rmse: 3.44338
# [119]	valid_0's rmse: 3.43808
# [120]	valid_0's rmse: 3.43372
# [121]	valid_0's rmse: 3.43029
# [122]	valid_0's rmse: 3.43029
# [123]	valid_0's rmse: 3.42936
# [124]	valid_0's rmse: 3.42414
# [125]	valid_0's rmse: 3.42447
# [126]	valid_0's rmse: 3.4246
# [127]	valid_0's rmse: 3.4238
# [128]	valid_0's rmse: 3.42042
# [129]	valid_0's rmse: 3.42041
# [130]	valid_0's rmse: 3.41873
# [131]	valid_0's rmse: 3.41817
# [132]	valid_0's rmse: 3.41567
# [133]	valid_0's rmse: 3.41358
# [134]	valid_0's rmse: 3.41279
# [135]	valid_0's rmse: 3.4093
# [136]	valid_0's rmse: 3.40774
# [137]	valid_0's rmse: 3.40208
# [138]	valid_0's rmse: 3.39342
# [139]	valid_0's rmse: 3.39249
# [140]	valid_0's rmse: 3.39063
# [141]	valid_0's rmse: 3.38223
# [142]	valid_0's rmse: 3.38029
# [143]	valid_0's rmse: 3.38303
# [144]	valid_0's rmse: 3.38473
# [145]	valid_0's rmse: 3.38301
# [146]	valid_0's rmse: 3.38183
# [147]	valid_0's rmse: 3.38048
# Early stopping, best iteration is:
# [142]	valid_0's rmse: 3.38029
# [1.6GB(+0.0GB): 16.416sec] fit X
# [1]	valid_0's rmse: 38.9427
# Training until validation scores don't improve for 5 rounds
# [2]	valid_0's rmse: 35.2092
# [3]	valid_0's rmse: 31.9009
# [4]	valid_0's rmse: 28.8819
# [5]	valid_0's rmse: 26.0993
# [6]	valid_0's rmse: 23.6823
# [7]	valid_0's rmse: 21.4658
# [8]	valid_0's rmse: 19.5053
# [9]	valid_0's rmse: 17.7007
# [10]	valid_0's rmse: 16.0946
# [11]	valid_0's rmse: 14.672
# [12]	valid_0's rmse: 13.366
# [13]	valid_0's rmse: 12.2205
# [14]	valid_0's rmse: 11.2004
# [15]	valid_0's rmse: 10.2655
# [16]	valid_0's rmse: 9.43922
# [17]	valid_0's rmse: 8.703
# [18]	valid_0's rmse: 8.04645
# [19]	valid_0's rmse: 7.44988
# [20]	valid_0's rmse: 6.9276
# [21]	valid_0's rmse: 6.47824
# [22]	valid_0's rmse: 6.07998
# [23]	valid_0's rmse: 5.73816
# [24]	valid_0's rmse: 5.43614
# [25]	valid_0's rmse: 5.17852
# [26]	valid_0's rmse: 4.94301
# [27]	valid_0's rmse: 4.7257
# [28]	valid_0's rmse: 4.55587
# [29]	valid_0's rmse: 4.39168
# [30]	valid_0's rmse: 4.25852
# [31]	valid_0's rmse: 4.12609
# [32]	valid_0's rmse: 4.02393
# [33]	valid_0's rmse: 3.93322
# [34]	valid_0's rmse: 3.84605
# [35]	valid_0's rmse: 3.78366
# [36]	valid_0's rmse: 3.72373
# [37]	valid_0's rmse: 3.66901
# [38]	valid_0's rmse: 3.62755
# [39]	valid_0's rmse: 3.58582
# [40]	valid_0's rmse: 3.55963
# [41]	valid_0's rmse: 3.53247
# [42]	valid_0's rmse: 3.51069
# [43]	valid_0's rmse: 3.48358
# [44]	valid_0's rmse: 3.46665
# [45]	valid_0's rmse: 3.43846
# [46]	valid_0's rmse: 3.42388
# [47]	valid_0's rmse: 3.40405
# [48]	valid_0's rmse: 3.38483
# [49]	valid_0's rmse: 3.37179
# [50]	valid_0's rmse: 3.35764
# [51]	valid_0's rmse: 3.33677
# [52]	valid_0's rmse: 3.31196
# [53]	valid_0's rmse: 3.29813
# [54]	valid_0's rmse: 3.28868
# [55]	valid_0's rmse: 3.27914
# [56]	valid_0's rmse: 3.26226
# [57]	valid_0's rmse: 3.25299
# [58]	valid_0's rmse: 3.2384
# [59]	valid_0's rmse: 3.2213
# [60]	valid_0's rmse: 3.20581
# [61]	valid_0's rmse: 3.19885
# [62]	valid_0's rmse: 3.19431
# [63]	valid_0's rmse: 3.18733
# [64]	valid_0's rmse: 3.18115
# [65]	valid_0's rmse: 3.17406
# [66]	valid_0's rmse: 3.16436
# [67]	valid_0's rmse: 3.15642
# [68]	valid_0's rmse: 3.14755
# [69]	valid_0's rmse: 3.14394
# [70]	valid_0's rmse: 3.14271
# [71]	valid_0's rmse: 3.1457
# [72]	valid_0's rmse: 3.1422
# [73]	valid_0's rmse: 3.13126
# [74]	valid_0's rmse: 3.12228
# [75]	valid_0's rmse: 3.11387
# [76]	valid_0's rmse: 3.1093
# [77]	valid_0's rmse: 3.10439
# [78]	valid_0's rmse: 3.09591
# [79]	valid_0's rmse: 3.08856
# [80]	valid_0's rmse: 3.08233
# [81]	valid_0's rmse: 3.06939
# [82]	valid_0's rmse: 3.06284
# [83]	valid_0's rmse: 3.06135
# [84]	valid_0's rmse: 3.06196
# [85]	valid_0's rmse: 3.05626
# [86]	valid_0's rmse: 3.04849
# [87]	valid_0's rmse: 3.04311
# [88]	valid_0's rmse: 3.03958
# [89]	valid_0's rmse: 3.02951
# [90]	valid_0's rmse: 3.01964
# [91]	valid_0's rmse: 3.01284
# [92]	valid_0's rmse: 3.00457
# [93]	valid_0's rmse: 2.99734
# [94]	valid_0's rmse: 2.98729
# [95]	valid_0's rmse: 2.9851
# [96]	valid_0's rmse: 2.98086
# [97]	valid_0's rmse: 2.97772
# [98]	valid_0's rmse: 2.97194
# [99]	valid_0's rmse: 2.96707
# [100]	valid_0's rmse: 2.96406
# [101]	valid_0's rmse: 2.96077
# [102]	valid_0's rmse: 2.95853
# [103]	valid_0's rmse: 2.95212
# [104]	valid_0's rmse: 2.94649
# [105]	valid_0's rmse: 2.93909
# [106]	valid_0's rmse: 2.93415
# [107]	valid_0's rmse: 2.93547
# [108]	valid_0's rmse: 2.9326
# [109]	valid_0's rmse: 2.9235
# [110]	valid_0's rmse: 2.92106
# [111]	valid_0's rmse: 2.92234
# [112]	valid_0's rmse: 2.91772
# [113]	valid_0's rmse: 2.91351
# [114]	valid_0's rmse: 2.91174
# [115]	valid_0's rmse: 2.91112
# [116]	valid_0's rmse: 2.91042
# [117]	valid_0's rmse: 2.90616
# [118]	valid_0's rmse: 2.90239
# [119]	valid_0's rmse: 2.89406
# [120]	valid_0's rmse: 2.88644
# [121]	valid_0's rmse: 2.88016
# [122]	valid_0's rmse: 2.87387
# [123]	valid_0's rmse: 2.87251
# [124]	valid_0's rmse: 2.87174
# [125]	valid_0's rmse: 2.86887
# [126]	valid_0's rmse: 2.86767
# [127]	valid_0's rmse: 2.86514
# [128]	valid_0's rmse: 2.86537
# [129]	valid_0's rmse: 2.86363
# [130]	valid_0's rmse: 2.85978
# [131]	valid_0's rmse: 2.86152
# [132]	valid_0's rmse: 2.86126
# [133]	valid_0's rmse: 2.86165
# [134]	valid_0's rmse: 2.8603
# [135]	valid_0's rmse: 2.85617
# [136]	valid_0's rmse: 2.85313
# [137]	valid_0's rmse: 2.85176
# [138]	valid_0's rmse: 2.85057
# [139]	valid_0's rmse: 2.85179
# [140]	valid_0's rmse: 2.85
# [141]	valid_0's rmse: 2.84446
# [142]	valid_0's rmse: 2.84236
# [143]	valid_0's rmse: 2.83784
# [144]	valid_0's rmse: 2.83585
# [145]	valid_0's rmse: 2.83297
# [146]	valid_0's rmse: 2.82954
# [147]	valid_0's rmse: 2.83034
# [148]	valid_0's rmse: 2.83004
# [149]	valid_0's rmse: 2.82841
# [150]	valid_0's rmse: 2.82846
# [151]	valid_0's rmse: 2.82795
# [152]	valid_0's rmse: 2.83
# [153]	valid_0's rmse: 2.82846
# [154]	valid_0's rmse: 2.82678
# [155]	valid_0's rmse: 2.82714
# [156]	valid_0's rmse: 2.82581
# [157]	valid_0's rmse: 2.82491
# [158]	valid_0's rmse: 2.82718
# [159]	valid_0's rmse: 2.82656
# [160]	valid_0's rmse: 2.82528
# [161]	valid_0's rmse: 2.82267
# [162]	valid_0's rmse: 2.81884
# [163]	valid_0's rmse: 2.81866
# [164]	valid_0's rmse: 2.81713
# [165]	valid_0's rmse: 2.8166
# [166]	valid_0's rmse: 2.81311
# [167]	valid_0's rmse: 2.81023
# [168]	valid_0's rmse: 2.80634
# [169]	valid_0's rmse: 2.80585
# [170]	valid_0's rmse: 2.80691
# [171]	valid_0's rmse: 2.80669
# [172]	valid_0's rmse: 2.80533
# [173]	valid_0's rmse: 2.80422
# [174]	valid_0's rmse: 2.80105
# [175]	valid_0's rmse: 2.79837
# [176]	valid_0's rmse: 2.79819
# [177]	valid_0's rmse: 2.79416
# [178]	valid_0's rmse: 2.79333
# [179]	valid_0's rmse: 2.79225
# [180]	valid_0's rmse: 2.79011
# [181]	valid_0's rmse: 2.78977
# [182]	valid_0's rmse: 2.79091
# [183]	valid_0's rmse: 2.79158
# [184]	valid_0's rmse: 2.79248
# [185]	valid_0's rmse: 2.79459
# [186]	valid_0's rmse: 2.79694
# Early stopping, best iteration is:
# [181]	valid_0's rmse: 2.78977
# [1.6GB(-0.0GB): 17.128sec] fit Y
# [1]	valid_0's multi_logloss: 1.26915
# Training until validation scores don't improve for 5 rounds
# [2]	valid_0's multi_logloss: 1.04649
# [3]	valid_0's multi_logloss: 0.876557
# [4]	valid_0's multi_logloss: 0.74128
# [5]	valid_0's multi_logloss: 0.634195
# [6]	valid_0's multi_logloss: 0.546652
# [7]	valid_0's multi_logloss: 0.472681
# [8]	valid_0's multi_logloss: 0.411154
# [9]	valid_0's multi_logloss: 0.359248
# [10]	valid_0's multi_logloss: 0.314572
# [11]	valid_0's multi_logloss: 0.277326
# [12]	valid_0's multi_logloss: 0.245231
# [13]	valid_0's multi_logloss: 0.216809
# [14]	valid_0's multi_logloss: 0.192897
# [15]	valid_0's multi_logloss: 0.1717
# [16]	valid_0's multi_logloss: 0.153003
# [17]	valid_0's multi_logloss: 0.137476
# [18]	valid_0's multi_logloss: 0.124133
# [19]	valid_0's multi_logloss: 0.112122
# [20]	valid_0's multi_logloss: 0.101609
# [21]	valid_0's multi_logloss: 0.0923388
# [22]	valid_0's multi_logloss: 0.0841162
# [23]	valid_0's multi_logloss: 0.0767611
# [24]	valid_0's multi_logloss: 0.0704625
# [25]	valid_0's multi_logloss: 0.0650042
# [26]	valid_0's multi_logloss: 0.0605004
# [27]	valid_0's multi_logloss: 0.056396
# [28]	valid_0's multi_logloss: 0.0525557
# [29]	valid_0's multi_logloss: 0.0493131
# [30]	valid_0's multi_logloss: 0.0464061
# [31]	valid_0's multi_logloss: 0.0439654
# [32]	valid_0's multi_logloss: 0.0416653
# [33]	valid_0's multi_logloss: 0.0395921
# [34]	valid_0's multi_logloss: 0.0378416
# [35]	valid_0's multi_logloss: 0.0360033
# [36]	valid_0's multi_logloss: 0.0344788
# [37]	valid_0's multi_logloss: 0.0333257
# [38]	valid_0's multi_logloss: 0.0323468
# [39]	valid_0's multi_logloss: 0.0315155
# [40]	valid_0's multi_logloss: 0.030699
# [41]	valid_0's multi_logloss: 0.0301146
# [42]	valid_0's multi_logloss: 0.0295988
# [43]	valid_0's multi_logloss: 0.0290985
# [44]	valid_0's multi_logloss: 0.0287561
# [45]	valid_0's multi_logloss: 0.0284232
# [46]	valid_0's multi_logloss: 0.0281983
# [47]	valid_0's multi_logloss: 0.0277963
# [48]	valid_0's multi_logloss: 0.0276131
# [49]	valid_0's multi_logloss: 0.027288
# [50]	valid_0's multi_logloss: 0.0270882
# [51]	valid_0's multi_logloss: 0.0268223
# [52]	valid_0's multi_logloss: 0.0266405
# [53]	valid_0's multi_logloss: 0.0265303
# [54]	valid_0's multi_logloss: 0.0264184
# [55]	valid_0's multi_logloss: 0.0263451
# [56]	valid_0's multi_logloss: 0.0262596
# [57]	valid_0's multi_logloss: 0.0261314
# [58]	valid_0's multi_logloss: 0.026022
# [59]	valid_0's multi_logloss: 0.0259551
# [60]	valid_0's multi_logloss: 0.0259542
# [61]	valid_0's multi_logloss: 0.0257378
# [62]	valid_0's multi_logloss: 0.0256898
# [63]	valid_0's multi_logloss: 0.0255573
# [64]	valid_0's multi_logloss: 0.0254986
# [65]	valid_0's multi_logloss: 0.0253437
# [66]	valid_0's multi_logloss: 0.025304
# [67]	valid_0's multi_logloss: 0.0252595
# [68]	valid_0's multi_logloss: 0.025232
# [69]	valid_0's multi_logloss: 0.0251673
# [70]	valid_0's multi_logloss: 0.0251665
# [71]	valid_0's multi_logloss: 0.0250044
# [72]	valid_0's multi_logloss: 0.0249482
# [73]	valid_0's multi_logloss: 0.0249482
# [74]	valid_0's multi_logloss: 0.0249482
# [75]	valid_0's multi_logloss: 0.0249147
# [76]	valid_0's multi_logloss: 0.0248938
# [77]	valid_0's multi_logloss: 0.0248612
# [78]	valid_0's multi_logloss: 0.0248401
# [79]	valid_0's multi_logloss: 0.0247533
# [80]	valid_0's multi_logloss: 0.0247399
# [81]	valid_0's multi_logloss: 0.024734
# [82]	valid_0's multi_logloss: 0.0247276
# [83]	valid_0's multi_logloss: 0.0247234
# [84]	valid_0's multi_logloss: 0.0246932
# [85]	valid_0's multi_logloss: 0.0246929
# [86]	valid_0's multi_logloss: 0.0246929
# [87]	valid_0's multi_logloss: 0.0246924
# [88]	valid_0's multi_logloss: 0.024679
# [89]	valid_0's multi_logloss: 0.024625
# [90]	valid_0's multi_logloss: 0.0245885
# [91]	valid_0's multi_logloss: 0.0245594
# [92]	valid_0's multi_logloss: 0.0244542
# [93]	valid_0's multi_logloss: 0.024443
# [94]	valid_0's multi_logloss: 0.024443
# [95]	valid_0's multi_logloss: 0.024443
# [96]	valid_0's multi_logloss: 0.024443
# [97]	valid_0's multi_logloss: 0.024443
# [98]	valid_0's multi_logloss: 0.0244376
# [99]	valid_0's multi_logloss: 0.0244367
# [100]	valid_0's multi_logloss: 0.0244164
# [101]	valid_0's multi_logloss: 0.0244151
# [102]	valid_0's multi_logloss: 0.0244151
# [103]	valid_0's multi_logloss: 0.0244122
# [104]	valid_0's multi_logloss: 0.0244122
# [105]	valid_0's multi_logloss: 0.0244118
# [106]	valid_0's multi_logloss: 0.0244118
# [107]	valid_0's multi_logloss: 0.0244083
# [108]	valid_0's multi_logloss: 0.0244076
# [109]	valid_0's multi_logloss: 0.0244076
# [110]	valid_0's multi_logloss: 0.0243736
# [111]	valid_0's multi_logloss: 0.0243732
# [112]	valid_0's multi_logloss: 0.0243658
# [113]	valid_0's multi_logloss: 0.0243584
# [114]	valid_0's multi_logloss: 0.0243583
# [115]	valid_0's multi_logloss: 0.0243583
# [116]	valid_0's multi_logloss: 0.0243583
# [117]	valid_0's multi_logloss: 0.0243583
# [118]	valid_0's multi_logloss: 0.0243583
# [119]	valid_0's multi_logloss: 0.0243582
# [120]	valid_0's multi_logloss: 0.0243576
# [121]	valid_0's multi_logloss: 0.0243564
# [122]	valid_0's multi_logloss: 0.0243506
# [123]	valid_0's multi_logloss: 0.0243482
# [124]	valid_0's multi_logloss: 0.0243461
# [125]	valid_0's multi_logloss: 0.0243451
# [126]	valid_0's multi_logloss: 0.0243445
# [127]	valid_0's multi_logloss: 0.024344
# [128]	valid_0's multi_logloss: 0.0243435
# [129]	valid_0's multi_logloss: 0.024337
# [130]	valid_0's multi_logloss: 0.0242932
# [131]	valid_0's multi_logloss: 0.024213
# [132]	valid_0's multi_logloss: 0.024213
# [133]	valid_0's multi_logloss: 0.0242125
# [134]	valid_0's multi_logloss: 0.0242064
# [135]	valid_0's multi_logloss: 0.0242064
# [136]	valid_0's multi_logloss: 0.0242064
# [137]	valid_0's multi_logloss: 0.0242064
# [138]	valid_0's multi_logloss: 0.0241976
# [139]	valid_0's multi_logloss: 0.0241976
# [140]	valid_0's multi_logloss: 0.0241938
# [141]	valid_0's multi_logloss: 0.0241934
# [142]	valid_0's multi_logloss: 0.0241868
# [143]	valid_0's multi_logloss: 0.0241858
# [144]	valid_0's multi_logloss: 0.0241856
# [145]	valid_0's multi_logloss: 0.024184
# [146]	valid_0's multi_logloss: 0.024184
# [147]	valid_0's multi_logloss: 0.0241828
# [148]	valid_0's multi_logloss: 0.0241585
# [149]	valid_0's multi_logloss: 0.0241521
# [150]	valid_0's multi_logloss: 0.0241521
# [151]	valid_0's multi_logloss: 0.0241521
# [152]	valid_0's multi_logloss: 0.0241521
# [153]	valid_0's multi_logloss: 0.0241521
# [154]	valid_0's multi_logloss: 0.0241521
# Early stopping, best iteration is:
# [149]	valid_0's multi_logloss: 0.0241521
# [1.6GB(+0.0GB): 27.515sec] fit F
# fold 1: mean position error 3.5324758640032607
# [1]	valid_0's rmse: 47.953
# Training until validation scores don't improve for 5 rounds
# [2]	valid_0's rmse: 43.502
# [3]	valid_0's rmse: 39.5601
# [4]	valid_0's rmse: 35.953
# [5]	valid_0's rmse: 32.6989
# [6]	valid_0's rmse: 29.7008
# [7]	valid_0's rmse: 27.0678
# [8]	valid_0's rmse: 24.7074
# [9]	valid_0's rmse: 22.5494
# [10]	valid_0's rmse: 20.6297
# [11]	valid_0's rmse: 18.8862
# [12]	valid_0's rmse: 17.2925
# [13]	valid_0's rmse: 15.897
# [14]	valid_0's rmse: 14.6489
# [15]	valid_0's rmse: 13.5557
# [16]	valid_0's rmse: 12.5296
# [17]	valid_0's rmse: 11.6502
# [18]	valid_0's rmse: 10.8295
# [19]	valid_0's rmse: 10.0939
# [20]	valid_0's rmse: 9.47391
# [21]	valid_0's rmse: 8.88545
# [22]	valid_0's rmse: 8.41291
# [23]	valid_0's rmse: 7.98685
# [24]	valid_0's rmse: 7.57136
# [25]	valid_0's rmse: 7.23707
# [26]	valid_0's rmse: 6.94211
# [27]	valid_0's rmse: 6.6746
# [28]	valid_0's rmse: 6.44265
# [29]	valid_0's rmse: 6.24002
# [30]	valid_0's rmse: 6.051
# [31]	valid_0's rmse: 5.89221
# [32]	valid_0's rmse: 5.74755
# [33]	valid_0's rmse: 5.62444
# [34]	valid_0's rmse: 5.52655
# [35]	valid_0's rmse: 5.44314
# [36]	valid_0's rmse: 5.3563
# [37]	valid_0's rmse: 5.2821
# [38]	valid_0's rmse: 5.19562
# [39]	valid_0's rmse: 5.13547
# [40]	valid_0's rmse: 5.08559
# [41]	valid_0's rmse: 5.03496
# [42]	valid_0's rmse: 4.98311
# [43]	valid_0's rmse: 4.9561
# [44]	valid_0's rmse: 4.92631
# [45]	valid_0's rmse: 4.88175
# [46]	valid_0's rmse: 4.85951
# [47]	valid_0's rmse: 4.83526
# [48]	valid_0's rmse: 4.8173
# [49]	valid_0's rmse: 4.80019
# [50]	valid_0's rmse: 4.77786
# [51]	valid_0's rmse: 4.76497
# [52]	valid_0's rmse: 4.7492
# [53]	valid_0's rmse: 4.72202
# [54]	valid_0's rmse: 4.71144
# [55]	valid_0's rmse: 4.68568
# [56]	valid_0's rmse: 4.66571
# [57]	valid_0's rmse: 4.64729
# [58]	valid_0's rmse: 4.62564
# [59]	valid_0's rmse: 4.61013
# [60]	valid_0's rmse: 4.59843
# [61]	valid_0's rmse: 4.58518
# [62]	valid_0's rmse: 4.56629
# [63]	valid_0's rmse: 4.54738
# [64]	valid_0's rmse: 4.54166
# [65]	valid_0's rmse: 4.52842
# [66]	valid_0's rmse: 4.51839
# [67]	valid_0's rmse: 4.50394
# [68]	valid_0's rmse: 4.4883
# [69]	valid_0's rmse: 4.48057
# [70]	valid_0's rmse: 4.46778
# [71]	valid_0's rmse: 4.45374
# [72]	valid_0's rmse: 4.4344
# [73]	valid_0's rmse: 4.42189
# [74]	valid_0's rmse: 4.41021
# [75]	valid_0's rmse: 4.3933
# [76]	valid_0's rmse: 4.386
# [77]	valid_0's rmse: 4.37199
# [78]	valid_0's rmse: 4.36397
# [79]	valid_0's rmse: 4.35861
# [80]	valid_0's rmse: 4.35386
# [81]	valid_0's rmse: 4.35219
# [82]	valid_0's rmse: 4.33898
# [83]	valid_0's rmse: 4.32811
# [84]	valid_0's rmse: 4.32564
# [85]	valid_0's rmse: 4.31892
# [86]	valid_0's rmse: 4.32288
# [87]	valid_0's rmse: 4.30837
# [88]	valid_0's rmse: 4.29716
# [89]	valid_0's rmse: 4.28517
# [90]	valid_0's rmse: 4.27666
# [91]	valid_0's rmse: 4.26712
# [92]	valid_0's rmse: 4.25963
# [93]	valid_0's rmse: 4.25154
# [94]	valid_0's rmse: 4.25056
# [95]	valid_0's rmse: 4.24733
# [96]	valid_0's rmse: 4.24371
# [97]	valid_0's rmse: 4.23488
# [98]	valid_0's rmse: 4.23205
# [99]	valid_0's rmse: 4.22541
# [100]	valid_0's rmse: 4.21807
# [101]	valid_0's rmse: 4.22155
# [102]	valid_0's rmse: 4.21723
# [103]	valid_0's rmse: 4.21431
# [104]	valid_0's rmse: 4.21257
# [105]	valid_0's rmse: 4.2123
# [106]	valid_0's rmse: 4.21468
# [107]	valid_0's rmse: 4.21292
# [108]	valid_0's rmse: 4.2005
# [109]	valid_0's rmse: 4.19892
# [110]	valid_0's rmse: 4.18791
# [111]	valid_0's rmse: 4.18493
# [112]	valid_0's rmse: 4.18084
# [113]	valid_0's rmse: 4.17242
# [114]	valid_0's rmse: 4.17286
# [115]	valid_0's rmse: 4.1745
# [116]	valid_0's rmse: 4.1706
# [117]	valid_0's rmse: 4.17052
# [118]	valid_0's rmse: 4.1687
# [119]	valid_0's rmse: 4.16843
# [120]	valid_0's rmse: 4.16769
# [121]	valid_0's rmse: 4.16065
# [122]	valid_0's rmse: 4.1559
# [123]	valid_0's rmse: 4.15029
# [124]	valid_0's rmse: 4.14484
# [125]	valid_0's rmse: 4.13983
# [126]	valid_0's rmse: 4.1415
# [127]	valid_0's rmse: 4.13916
# [128]	valid_0's rmse: 4.13376
# [129]	valid_0's rmse: 4.13191
# [130]	valid_0's rmse: 4.12713
# [131]	valid_0's rmse: 4.11984
# [132]	valid_0's rmse: 4.11884
# [133]	valid_0's rmse: 4.11326
# [134]	valid_0's rmse: 4.11446
# [135]	valid_0's rmse: 4.10807
# [136]	valid_0's rmse: 4.10284
# [137]	valid_0's rmse: 4.10246
# [138]	valid_0's rmse: 4.10232
# [139]	valid_0's rmse: 4.1018
# [140]	valid_0's rmse: 4.09712
# [141]	valid_0's rmse: 4.09338
# [142]	valid_0's rmse: 4.09348
# [143]	valid_0's rmse: 4.09059
# [144]	valid_0's rmse: 4.09243
# [145]	valid_0's rmse: 4.09112
# [146]	valid_0's rmse: 4.09078
# [147]	valid_0's rmse: 4.09087
# [148]	valid_0's rmse: 4.09074
# Early stopping, best iteration is:
# [143]	valid_0's rmse: 4.09059
# [1.8GB(+0.1GB): 16.558sec] fit X
# [1]	valid_0's rmse: 39.3502
# Training until validation scores don't improve for 5 rounds
# [2]	valid_0's rmse: 35.6415
# [3]	valid_0's rmse: 32.3356
# [4]	valid_0's rmse: 29.3305
# [5]	valid_0's rmse: 26.6334
# [6]	valid_0's rmse: 24.1851
# [7]	valid_0's rmse: 22.025
# [8]	valid_0's rmse: 20.0622
# [9]	valid_0's rmse: 18.2687
# [10]	valid_0's rmse: 16.71
# [11]	valid_0's rmse: 15.3121
# [12]	valid_0's rmse: 14.0405
# [13]	valid_0's rmse: 12.8787
# [14]	valid_0's rmse: 11.8456
# [15]	valid_0's rmse: 10.8843
# [16]	valid_0's rmse: 10.0655
# [17]	valid_0's rmse: 9.31668
# [18]	valid_0's rmse: 8.64272
# [19]	valid_0's rmse: 8.05319
# [20]	valid_0's rmse: 7.51819
# [21]	valid_0's rmse: 7.02441
# [22]	valid_0's rmse: 6.59856
# [23]	valid_0's rmse: 6.2378
# [24]	valid_0's rmse: 5.91005
# [25]	valid_0's rmse: 5.62052
# [26]	valid_0's rmse: 5.36922
# [27]	valid_0's rmse: 5.13508
# [28]	valid_0's rmse: 4.93192
# [29]	valid_0's rmse: 4.76311
# [30]	valid_0's rmse: 4.60234
# [31]	valid_0's rmse: 4.45804
# [32]	valid_0's rmse: 4.32568
# [33]	valid_0's rmse: 4.22272
# [34]	valid_0's rmse: 4.11337
# [35]	valid_0's rmse: 4.02809
# [36]	valid_0's rmse: 3.94508
# [37]	valid_0's rmse: 3.87125
# [38]	valid_0's rmse: 3.80758
# [39]	valid_0's rmse: 3.74703
# [40]	valid_0's rmse: 3.69144
# [41]	valid_0's rmse: 3.64473
# [42]	valid_0's rmse: 3.60257
# [43]	valid_0's rmse: 3.56805
# [44]	valid_0's rmse: 3.53056
# [45]	valid_0's rmse: 3.50048
# [46]	valid_0's rmse: 3.47916
# [47]	valid_0's rmse: 3.45045
# [48]	valid_0's rmse: 3.42455
# [49]	valid_0's rmse: 3.39794
# [50]	valid_0's rmse: 3.37182
# [51]	valid_0's rmse: 3.351
# [52]	valid_0's rmse: 3.32961
# [53]	valid_0's rmse: 3.30842
# [54]	valid_0's rmse: 3.29424
# [55]	valid_0's rmse: 3.27753
# [56]	valid_0's rmse: 3.26172
# [57]	valid_0's rmse: 3.23948
# [58]	valid_0's rmse: 3.2237
# [59]	valid_0's rmse: 3.2118
# [60]	valid_0's rmse: 3.19779
# [61]	valid_0's rmse: 3.17846
# [62]	valid_0's rmse: 3.16611
# [63]	valid_0's rmse: 3.15996
# [64]	valid_0's rmse: 3.14572
# [65]	valid_0's rmse: 3.13084
# [66]	valid_0's rmse: 3.11996
# [67]	valid_0's rmse: 3.10194
# [68]	valid_0's rmse: 3.08882
# [69]	valid_0's rmse: 3.07665
# [70]	valid_0's rmse: 3.06703
# [71]	valid_0's rmse: 3.05929
# [72]	valid_0's rmse: 3.05325
# [73]	valid_0's rmse: 3.05118
# [74]	valid_0's rmse: 3.04346
# [75]	valid_0's rmse: 3.03102
# [76]	valid_0's rmse: 3.02602
# [77]	valid_0's rmse: 3.01568
# [78]	valid_0's rmse: 3.00803
# [79]	valid_0's rmse: 3.00208
# [80]	valid_0's rmse: 2.997
# [81]	valid_0's rmse: 2.9868
# [82]	valid_0's rmse: 2.98072
# [83]	valid_0's rmse: 2.97506
# [84]	valid_0's rmse: 2.96997
# [85]	valid_0's rmse: 2.96055
# [86]	valid_0's rmse: 2.95559
# [87]	valid_0's rmse: 2.94856
# [88]	valid_0's rmse: 2.93687
# [89]	valid_0's rmse: 2.93183
# [90]	valid_0's rmse: 2.92504
# [91]	valid_0's rmse: 2.92117
# [92]	valid_0's rmse: 2.91719
# [93]	valid_0's rmse: 2.9119
# [94]	valid_0's rmse: 2.90898
# [95]	valid_0's rmse: 2.91145
# [96]	valid_0's rmse: 2.90821
# [97]	valid_0's rmse: 2.90447
# [98]	valid_0's rmse: 2.90248
# [99]	valid_0's rmse: 2.89868
# [100]	valid_0's rmse: 2.8931
# [101]	valid_0's rmse: 2.89091
# [102]	valid_0's rmse: 2.88569
# [103]	valid_0's rmse: 2.88511
# [104]	valid_0's rmse: 2.88362
# [105]	valid_0's rmse: 2.87621
# [106]	valid_0's rmse: 2.87362
# [107]	valid_0's rmse: 2.87024
# [108]	valid_0's rmse: 2.86746
# [109]	valid_0's rmse: 2.86576
# [110]	valid_0's rmse: 2.86406
# [111]	valid_0's rmse: 2.8607
# [112]	valid_0's rmse: 2.85914
# [113]	valid_0's rmse: 2.85502
# [114]	valid_0's rmse: 2.84906
# [115]	valid_0's rmse: 2.84596
# [116]	valid_0's rmse: 2.84208
# [117]	valid_0's rmse: 2.84043
# [118]	valid_0's rmse: 2.84173
# [119]	valid_0's rmse: 2.84054
# [120]	valid_0's rmse: 2.83998
# [121]	valid_0's rmse: 2.83651
# [122]	valid_0's rmse: 2.83703
# [123]	valid_0's rmse: 2.83162
# [124]	valid_0's rmse: 2.82974
# [125]	valid_0's rmse: 2.82717
# [126]	valid_0's rmse: 2.82377
# [127]	valid_0's rmse: 2.81988
# [128]	valid_0's rmse: 2.81707
# [129]	valid_0's rmse: 2.81488
# [130]	valid_0's rmse: 2.8129
# [131]	valid_0's rmse: 2.81039
# [132]	valid_0's rmse: 2.81062
# [133]	valid_0's rmse: 2.80826
# [134]	valid_0's rmse: 2.80867
# [135]	valid_0's rmse: 2.80431
# [136]	valid_0's rmse: 2.80155
# [137]	valid_0's rmse: 2.79895
# [138]	valid_0's rmse: 2.79897
# [139]	valid_0's rmse: 2.79421
# [140]	valid_0's rmse: 2.79327
# [141]	valid_0's rmse: 2.79518
# [142]	valid_0's rmse: 2.79243
# [143]	valid_0's rmse: 2.79362
# [144]	valid_0's rmse: 2.79482
# [145]	valid_0's rmse: 2.79185
# [146]	valid_0's rmse: 2.78927
# [147]	valid_0's rmse: 2.78605
# [148]	valid_0's rmse: 2.78381
# [149]	valid_0's rmse: 2.78066
# [150]	valid_0's rmse: 2.77455
# [151]	valid_0's rmse: 2.77495
# [152]	valid_0's rmse: 2.77136
# [153]	valid_0's rmse: 2.77165
# ...
# [23]	valid_0's multi_logloss: 0.0831155
# [24]	valid_0's multi_logloss: 0.0769272
# [25]	valid_0's multi_logloss: 0.0712433
# [26]	valid_0's multi_logloss: 0.0661748
# [27]	valid_0's multi_logloss: 0.0618652
# [28]	valid_0's multi_logloss: 0.0581187
# [29]	valid_0's multi_logloss: 0.0545416
# [30]	valid_0's multi_logloss: 0.0516174
# [31]	valid_0's multi_logloss: 0.0488474
# [32]	valid_0's multi_logloss: 0.0464414
# [33]	valid_0's multi_logloss: 0.0443139
# [34]	valid_0's multi_logloss: 0.0424492
# [35]	valid_0's multi_logloss: 0.0407771
# [36]	valid_0's multi_logloss: 0.0393514
# [37]	valid_0's multi_logloss: 0.0381954
# [38]	valid_0's multi_logloss: 0.0372033
# [39]	valid_0's multi_logloss: 0.0361326
# [40]	valid_0's multi_logloss: 0.0351109
# [41]	valid_0's multi_logloss: 0.0341686
# [42]	valid_0's multi_logloss: 0.0334014
# [43]	valid_0's multi_logloss: 0.0329582
# [44]	valid_0's multi_logloss: 0.0326117
# [45]	valid_0's multi_logloss: 0.0323378
# [46]	valid_0's multi_logloss: 0.0320236
# [47]	valid_0's multi_logloss: 0.0316115
# [48]	valid_0's multi_logloss: 0.0313563
# [49]	valid_0's multi_logloss: 0.0310479
# [50]	valid_0's multi_logloss: 0.0308109
# [51]	valid_0's multi_logloss: 0.030433
# [52]	valid_0's multi_logloss: 0.0303044
# [53]	valid_0's multi_logloss: 0.0299044
# [54]	valid_0's multi_logloss: 0.0297197
# [55]	valid_0's multi_logloss: 0.0296019
# [56]	valid_0's multi_logloss: 0.0295532
# [57]	valid_0's multi_logloss: 0.0294963
# [58]	valid_0's multi_logloss: 0.029407
# [59]	valid_0's multi_logloss: 0.0293474
# [60]	valid_0's multi_logloss: 0.029268
# [61]	valid_0's multi_logloss: 0.0291566
# [62]	valid_0's multi_logloss: 0.0290516
# [63]	valid_0's multi_logloss: 0.0289292
# [64]	valid_0's multi_logloss: 0.0289101
# [65]	valid_0's multi_logloss: 0.0289065
# [66]	valid_0's multi_logloss: 0.0289034
# [67]	valid_0's multi_logloss: 0.0287178
# [68]	valid_0's multi_logloss: 0.0285833
# [69]	valid_0's multi_logloss: 0.0285736
# [70]	valid_0's multi_logloss: 0.0285002
# [71]	valid_0's multi_logloss: 0.0284429
# [72]	valid_0's multi_logloss: 0.0284055
# [73]	valid_0's multi_logloss: 0.0282698
# [74]	valid_0's multi_logloss: 0.0282395
# [75]	valid_0's multi_logloss: 0.0282328
# [76]	valid_0's multi_logloss: 0.028228
# [77]	valid_0's multi_logloss: 0.0281931
# [78]	valid_0's multi_logloss: 0.0281418
# [79]	valid_0's multi_logloss: 0.0281343
# [80]	valid_0's multi_logloss: 0.0281285
# [81]	valid_0's multi_logloss: 0.0281257
# [82]	valid_0's multi_logloss: 0.0280906
# [83]	valid_0's multi_logloss: 0.0280849
# [84]	valid_0's multi_logloss: 0.0280841
# [85]	valid_0's multi_logloss: 0.0280523
# [86]	valid_0's multi_logloss: 0.0280495
# [87]	valid_0's multi_logloss: 0.0280023
# [88]	valid_0's multi_logloss: 0.0280022
# [89]	valid_0's multi_logloss: 0.0279729
# [90]	valid_0's multi_logloss: 0.0279326
# [91]	valid_0's multi_logloss: 0.0278196
# [92]	valid_0's multi_logloss: 0.027813
# [93]	valid_0's multi_logloss: 0.0277763
# [94]	valid_0's multi_logloss: 0.0277489
# [95]	valid_0's multi_logloss: 0.0276971
# [96]	valid_0's multi_logloss: 0.0276959
# [97]	valid_0's multi_logloss: 0.0276941
# [98]	valid_0's multi_logloss: 0.0276939
# [99]	valid_0's multi_logloss: 0.0276937
# [100]	valid_0's multi_logloss: 0.0276934
# [101]	valid_0's multi_logloss: 0.0276934
# [102]	valid_0's multi_logloss: 0.0276934
# [103]	valid_0's multi_logloss: 0.027691
# [104]	valid_0's multi_logloss: 0.0276907
# [105]	valid_0's multi_logloss: 0.0276688
# [106]	valid_0's multi_logloss: 0.0276549
# [107]	valid_0's multi_logloss: 0.0276549
# [108]	valid_0's multi_logloss: 0.0276549
# [109]	valid_0's multi_logloss: 0.0276549
# [110]	valid_0's multi_logloss: 0.0276549
# [111]	valid_0's multi_logloss: 0.0276549
# Early stopping, best iteration is:
# [106]	valid_0's multi_logloss: 0.0276549
# [1.5GB(-0.0GB): 22.022sec] fit F
# fold 5: mean position error 3.7722734263070077
# [1]	valid_0's rmse: 48.4428
# Training until validation scores don't improve for 5 rounds
# [2]	valid_0's rmse: 43.9583
# [3]	valid_0's rmse: 39.9178
# [4]	valid_0's rmse: 36.2429
# [5]	valid_0's rmse: 32.8927
# [6]	valid_0's rmse: 29.9507
# [7]	valid_0's rmse: 27.2277
# [8]	valid_0's rmse: 24.7893
# [9]	valid_0's rmse: 22.6356
# [10]	valid_0's rmse: 20.718
# [11]	valid_0's rmse: 18.9494
# [12]	valid_0's rmse: 17.3362
# [13]	valid_0's rmse: 15.9502
# [14]	valid_0's rmse: 14.6537
# [15]	valid_0's rmse: 13.4899
# [16]	valid_0's rmse: 12.4302
# [17]	valid_0's rmse: 11.4831
# [18]	valid_0's rmse: 10.6522
# [19]	valid_0's rmse: 9.89271
# [20]	valid_0's rmse: 9.2165
# [21]	valid_0's rmse: 8.62719
# [22]	valid_0's rmse: 8.09443
# [23]	valid_0's rmse: 7.61004
# [24]	valid_0's rmse: 7.18515
# [25]	valid_0's rmse: 6.82346
# [26]	valid_0's rmse: 6.50738
# [27]	valid_0's rmse: 6.20708
# [28]	valid_0's rmse: 5.96329
# [29]	valid_0's rmse: 5.74312
# [30]	valid_0's rmse: 5.53198
# [31]	valid_0's rmse: 5.3497
# [32]	valid_0's rmse: 5.19638
# [33]	valid_0's rmse: 5.04668
# [34]	valid_0's rmse: 4.92381
# [35]	valid_0's rmse: 4.81017
# [36]	valid_0's rmse: 4.71575
# [37]	valid_0's rmse: 4.62288
# [38]	valid_0's rmse: 4.55197
# [39]	valid_0's rmse: 4.47335
# [40]	valid_0's rmse: 4.40212
# [41]	valid_0's rmse: 4.34527
# [42]	valid_0's rmse: 4.2998
# [43]	valid_0's rmse: 4.25575
# [44]	valid_0's rmse: 4.21855
# [45]	valid_0's rmse: 4.18586
# [46]	valid_0's rmse: 4.16263
# [47]	valid_0's rmse: 4.13933
# [48]	valid_0's rmse: 4.11878
# [49]	valid_0's rmse: 4.07885
# [50]	valid_0's rmse: 4.05658
# [51]	valid_0's rmse: 4.03242
# [52]	valid_0's rmse: 4.01474
# [53]	valid_0's rmse: 4.00587
# [54]	valid_0's rmse: 3.9907
# [55]	valid_0's rmse: 3.96015
# [56]	valid_0's rmse: 3.94421
# [57]	valid_0's rmse: 3.92709
# [58]	valid_0's rmse: 3.90899
# [59]	valid_0's rmse: 3.88972
# [60]	valid_0's rmse: 3.88546
# [61]	valid_0's rmse: 3.87397
# [62]	valid_0's rmse: 3.86655
# [63]	valid_0's rmse: 3.85573
# [64]	valid_0's rmse: 3.84914
# [65]	valid_0's rmse: 3.84208
# [66]	valid_0's rmse: 3.82436
# [67]	valid_0's rmse: 3.81444
# [68]	valid_0's rmse: 3.80259
# [69]	valid_0's rmse: 3.78889
# [70]	valid_0's rmse: 3.78195
# [71]	valid_0's rmse: 3.77117
# [72]	valid_0's rmse: 3.76779
# [73]	valid_0's rmse: 3.76502
# [74]	valid_0's rmse: 3.75616
# [75]	valid_0's rmse: 3.74621
# [76]	valid_0's rmse: 3.73844
# [77]	valid_0's rmse: 3.73013
# [78]	valid_0's rmse: 3.71836
# [79]	valid_0's rmse: 3.71719
# [80]	valid_0's rmse: 3.70885
# [81]	valid_0's rmse: 3.69464
# [82]	valid_0's rmse: 3.69044
# [83]	valid_0's rmse: 3.68768
# [84]	valid_0's rmse: 3.68104
# [85]	valid_0's rmse: 3.67143
# [86]	valid_0's rmse: 3.66603
# [87]	valid_0's rmse: 3.66252
# [88]	valid_0's rmse: 3.65721
# [89]	valid_0's rmse: 3.65061
# [90]	valid_0's rmse: 3.64357
# [91]	valid_0's rmse: 3.63847
# [92]	valid_0's rmse: 3.63424
# [93]	valid_0's rmse: 3.63061
# [94]	valid_0's rmse: 3.62401
# [95]	valid_0's rmse: 3.61426
# [96]	valid_0's rmse: 3.60857
# [97]	valid_0's rmse: 3.60497
# [98]	valid_0's rmse: 3.60422
# [99]	valid_0's rmse: 3.59887
# [100]	valid_0's rmse: 3.59265
# [101]	valid_0's rmse: 3.588
# [102]	valid_0's rmse: 3.58014
# [103]	valid_0's rmse: 3.57817
# [104]	valid_0's rmse: 3.57165
# [105]	valid_0's rmse: 3.56337
# [106]	valid_0's rmse: 3.5631
# [107]	valid_0's rmse: 3.56115
# [108]	valid_0's rmse: 3.55574
# [109]	valid_0's rmse: 3.55845
# [110]	valid_0's rmse: 3.55275
# [111]	valid_0's rmse: 3.54919
# [112]	valid_0's rmse: 3.54552
# [113]	valid_0's rmse: 3.54341
# [114]	valid_0's rmse: 3.54357
# [115]	valid_0's rmse: 3.53753
# [116]	valid_0's rmse: 3.52878
# [117]	valid_0's rmse: 3.52024
# [118]	valid_0's rmse: 3.50957
# [119]	valid_0's rmse: 3.50545
# [120]	valid_0's rmse: 3.50508
# [121]	valid_0's rmse: 3.50185
# [122]	valid_0's rmse: 3.50019
# [123]	valid_0's rmse: 3.49236
# [124]	valid_0's rmse: 3.48767
# [125]	valid_0's rmse: 3.4807
# [126]	valid_0's rmse: 3.47652
# [127]	valid_0's rmse: 3.47222
# [128]	valid_0's rmse: 3.46945
# [129]	valid_0's rmse: 3.46553
# [130]	valid_0's rmse: 3.46063
# [131]	valid_0's rmse: 3.45919
# [132]	valid_0's rmse: 3.45483
# [133]	valid_0's rmse: 3.45133
# [134]	valid_0's rmse: 3.44762
# [135]	valid_0's rmse: 3.44515
# [136]	valid_0's rmse: 3.44039
# [137]	valid_0's rmse: 3.43927
# [138]	valid_0's rmse: 3.43437
# [139]	valid_0's rmse: 3.43005
# [140]	valid_0's rmse: 3.42616
# [141]	valid_0's rmse: 3.42192
# [142]	valid_0's rmse: 3.42332
# [143]	valid_0's rmse: 3.42105
# [144]	valid_0's rmse: 3.42232
# [145]	valid_0's rmse: 3.41847
# [146]	valid_0's rmse: 3.4183
# [147]	valid_0's rmse: 3.41921
# [148]	valid_0's rmse: 3.42001
# [149]	valid_0's rmse: 3.41764
# [150]	valid_0's rmse: 3.4146
# [151]	valid_0's rmse: 3.41265
# [152]	valid_0's rmse: 3.40679
# [153]	valid_0's rmse: 3.40799
# [154]	valid_0's rmse: 3.40581
# [155]	valid_0's rmse: 3.40154
# [156]	valid_0's rmse: 3.40028
# [157]	valid_0's rmse: 3.39957
# [158]	valid_0's rmse: 3.39663
# [159]	valid_0's rmse: 3.39636
# [160]	valid_0's rmse: 3.39594
# [161]	valid_0's rmse: 3.39474
# [162]	valid_0's rmse: 3.39375
# [163]	valid_0's rmse: 3.39289
# [164]	valid_0's rmse: 3.39135
# [165]	valid_0's rmse: 3.39145
# [166]	valid_0's rmse: 3.39191
# [167]	valid_0's rmse: 3.39094
# [168]	valid_0's rmse: 3.38859
# [169]	valid_0's rmse: 3.38658
# [170]	valid_0's rmse: 3.38408
# [171]	valid_0's rmse: 3.38344
# [172]	valid_0's rmse: 3.38048
# [173]	valid_0's rmse: 3.37649
# [174]	valid_0's rmse: 3.37355
# [175]	valid_0's rmse: 3.37238
# [176]	valid_0's rmse: 3.37262
# [177]	valid_0's rmse: 3.37388
# [178]	valid_0's rmse: 3.3685
# [179]	valid_0's rmse: 3.36533
# [180]	valid_0's rmse: 3.3649
# [181]	valid_0's rmse: 3.36169
# [182]	valid_0's rmse: 3.3609
# [183]	valid_0's rmse: 3.35984
# [184]	valid_0's rmse: 3.35779
# [185]	valid_0's rmse: 3.35631
# [186]	valid_0's rmse: 3.35331
# [187]	valid_0's rmse: 3.35483
# [188]	valid_0's rmse: 3.34994
# [189]	valid_0's rmse: 3.34862
# [190]	valid_0's rmse: 3.34649
# [191]	valid_0's rmse: 3.34787
# [192]	valid_0's rmse: 3.34976
# [193]	valid_0's rmse: 3.34946
# [194]	valid_0's rmse: 3.35068
# [195]	valid_0's rmse: 3.34787
# Early stopping, best iteration is:
# [190]	valid_0's rmse: 3.34649
# [1.8GB(+0.1GB): 19.736sec] fit X
# [1]	valid_0's rmse: 39.0185
# Training until validation scores don't improve for 5 rounds
# [2]	valid_0's rmse: 35.3208
# [3]	valid_0's rmse: 31.9674
# [4]	valid_0's rmse: 28.9582
# [5]	valid_0's rmse: 26.2022
# [6]	valid_0's rmse: 23.7383
# [7]	valid_0's rmse: 21.5387
# [8]	valid_0's rmse: 19.5896
# [9]	valid_0's rmse: 17.8281
# [10]	valid_0's rmse: 16.2546
# [11]	valid_0's rmse: 14.7895
# [12]	valid_0's rmse: 13.4892
# [13]	valid_0's rmse: 12.3535
# [14]	valid_0's rmse: 11.2902
# [15]	valid_0's rmse: 10.3338
# [16]	valid_0's rmse: 9.49046
# [17]	valid_0's rmse: 8.7317
# [18]	valid_0's rmse: 8.05086
# [19]	valid_0's rmse: 7.44927
# [20]	valid_0's rmse: 6.92384
# [21]	valid_0's rmse: 6.44596
# [22]	valid_0's rmse: 6.03314
# [23]	valid_0's rmse: 5.67662
# [24]	valid_0's rmse: 5.39043
# [25]	valid_0's rmse: 5.10398
# [26]	valid_0's rmse: 4.85427
# [27]	valid_0's rmse: 4.62148
# [28]	valid_0's rmse: 4.41618
# [29]	valid_0's rmse: 4.24601
# [30]	valid_0's rmse: 4.07689
# [31]	valid_0's rmse: 3.93075
# [32]	valid_0's rmse: 3.80901
# [33]	valid_0's rmse: 3.70991
# [34]	valid_0's rmse: 3.61271
# [35]	valid_0's rmse: 3.53677
# [36]	valid_0's rmse: 3.4782
# [37]	valid_0's rmse: 3.42657
# [38]	valid_0's rmse: 3.3762
# [39]	valid_0's rmse: 3.33029
# [40]	valid_0's rmse: 3.28339
# [41]	valid_0's rmse: 3.23786
# [42]	valid_0's rmse: 3.19798
# [43]	valid_0's rmse: 3.16091
# [44]	valid_0's rmse: 3.12667
# [45]	valid_0's rmse: 3.10756
# [46]	valid_0's rmse: 3.08523
# [47]	valid_0's rmse: 3.0635
# [48]	valid_0's rmse: 3.04008
# [49]	valid_0's rmse: 3.02272
# [50]	valid_0's rmse: 3.00894
# [51]	valid_0's rmse: 2.98798
# [52]	valid_0's rmse: 2.95989
# [53]	valid_0's rmse: 2.94565
# [54]	valid_0's rmse: 2.92593
# [55]	valid_0's rmse: 2.91336
# [56]	valid_0's rmse: 2.89934
# [57]	valid_0's rmse: 2.8817
# [58]	valid_0's rmse: 2.86442
# [59]	valid_0's rmse: 2.86346
# [60]	valid_0's rmse: 2.85655
# [61]	valid_0's rmse: 2.84997
# [62]	valid_0's rmse: 2.83839
# [63]	valid_0's rmse: 2.83281
# [64]	valid_0's rmse: 2.81924
# [65]	valid_0's rmse: 2.81366
# [66]	valid_0's rmse: 2.79834
# [67]	valid_0's rmse: 2.78523
# [68]	valid_0's rmse: 2.78196
# [69]	valid_0's rmse: 2.76987
# [70]	valid_0's rmse: 2.75624
# [71]	valid_0's rmse: 2.75469
# [72]	valid_0's rmse: 2.75052
# [73]	valid_0's rmse: 2.73882
# [74]	valid_0's rmse: 2.72894
# [75]	valid_0's rmse: 2.73127
# [76]	valid_0's rmse: 2.72475
# [77]	valid_0's rmse: 2.7178
# [78]	valid_0's rmse: 2.70837
# [79]	valid_0's rmse: 2.70045
# [80]	valid_0's rmse: 2.69654
# [81]	valid_0's rmse: 2.69164
# [82]	valid_0's rmse: 2.69415
# [83]	valid_0's rmse: 2.6831
# [84]	valid_0's rmse: 2.67947
# [85]	valid_0's rmse: 2.67313
# [86]	valid_0's rmse: 2.66805
# [87]	valid_0's rmse: 2.66239
# [88]	valid_0's rmse: 2.6552
# [89]	valid_0's rmse: 2.64894
# [90]	valid_0's rmse: 2.65107
# [91]	valid_0's rmse: 2.65142
# [92]	valid_0's rmse: 2.65131
# [93]	valid_0's rmse: 2.64773
# [94]	valid_0's rmse: 2.64684
# [95]	valid_0's rmse: 2.64543
# [96]	valid_0's rmse: 2.64374
# [97]	valid_0's rmse: 2.63797
# [98]	valid_0's rmse: 2.63227
# [99]	valid_0's rmse: 2.62925
# [100]	valid_0's rmse: 2.62561
# [101]	valid_0's rmse: 2.62456
# [102]	valid_0's rmse: 2.62416
# [103]	valid_0's rmse: 2.61678
# [104]	valid_0's rmse: 2.60992
# [105]	valid_0's rmse: 2.60481
# [106]	valid_0's rmse: 2.60326
# [107]	valid_0's rmse: 2.60243
# [108]	valid_0's rmse: 2.60196
# [109]	valid_0's rmse: 2.60737
# [110]	valid_0's rmse: 2.60157
# [111]	valid_0's rmse: 2.59662
# [112]	valid_0's rmse: 2.59808
# [113]	valid_0's rmse: 2.59563
# [114]	valid_0's rmse: 2.58818
# [115]	valid_0's rmse: 2.58481
# [116]	valid_0's rmse: 2.58349
# [117]	valid_0's rmse: 2.5819
# [118]	valid_0's rmse: 2.57985
# [119]	valid_0's rmse: 2.57817
# [120]	valid_0's rmse: 2.57726
# [121]	valid_0's rmse: 2.57276
# [122]	valid_0's rmse: 2.57017
# [123]	valid_0's rmse: 2.56783
# [124]	valid_0's rmse: 2.56608
# [125]	valid_0's rmse: 2.5667
# [126]	valid_0's rmse: 2.56245
# [127]	valid_0's rmse: 2.56159
# [128]	valid_0's rmse: 2.5622
# [129]	valid_0's rmse: 2.56119
# [130]	valid_0's rmse: 2.56158
# [131]	valid_0's rmse: 2.5612
# [132]	valid_0's rmse: 2.56335
# [133]	valid_0's rmse: 2.56182
# [134]	valid_0's rmse: 2.56141
# Early stopping, best iteration is:
# [129]	valid_0's rmse: 2.56119
# [1.8GB(-0.0GB): 13.812sec] fit Y
# [1]	valid_0's multi_logloss: 1.26696
# Training until validation scores don't improve for 5 rounds
# [2]	valid_0's multi_logloss: 1.03927
# [3]	valid_0's multi_logloss: 0.874416
# [4]	valid_0's multi_logloss: 0.741466
# [5]	valid_0's multi_logloss: 0.63538
# [6]	valid_0's multi_logloss: 0.547915
# [7]	valid_0's multi_logloss: 0.475101
# [8]	valid_0's multi_logloss: 0.414326
# [9]	valid_0's multi_logloss: 0.362765
# [10]	valid_0's multi_logloss: 0.319938
# [11]	valid_0's multi_logloss: 0.282765
# [12]	valid_0's multi_logloss: 0.250484
# [13]	valid_0's multi_logloss: 0.222855
# [14]	valid_0's multi_logloss: 0.199345
# [15]	valid_0's multi_logloss: 0.179067
# [16]	valid_0's multi_logloss: 0.161466
# [17]	valid_0's multi_logloss: 0.145868
# [18]	valid_0's multi_logloss: 0.131871
# [19]	valid_0's multi_logloss: 0.119484
# [20]	valid_0's multi_logloss: 0.109248
# [21]	valid_0's multi_logloss: 0.099978
# [22]	valid_0's multi_logloss: 0.0920375
# [23]	valid_0's multi_logloss: 0.0844878
# [24]	valid_0's multi_logloss: 0.0779174
# [25]	valid_0's multi_logloss: 0.0722064
# [26]	valid_0's multi_logloss: 0.0673477
# [27]	valid_0's multi_logloss: 0.0630095
# [28]	valid_0's multi_logloss: 0.0592942
# [29]	valid_0's multi_logloss: 0.0557781
# [30]	valid_0's multi_logloss: 0.0529489
# [31]	valid_0's multi_logloss: 0.0502916
# [32]	valid_0's multi_logloss: 0.0478243
# [33]	valid_0's multi_logloss: 0.0459394
# [34]	valid_0's multi_logloss: 0.0441484
# [35]	valid_0's multi_logloss: 0.0425331
# [36]	valid_0's multi_logloss: 0.0408676
# [37]	valid_0's multi_logloss: 0.039621
# [38]	valid_0's multi_logloss: 0.0386519
# [39]	valid_0's multi_logloss: 0.0375709
# [40]	valid_0's multi_logloss: 0.0365277
# [41]	valid_0's multi_logloss: 0.0358797
# [42]	valid_0's multi_logloss: 0.0352008
# [43]	valid_0's multi_logloss: 0.0347191
# [44]	valid_0's multi_logloss: 0.034334
# [45]	valid_0's multi_logloss: 0.0340607
# [46]	valid_0's multi_logloss: 0.0337349
# [47]	valid_0's multi_logloss: 0.0333178
# [48]	valid_0's multi_logloss: 0.0330794
# [49]	valid_0's multi_logloss: 0.0325688
# [50]	valid_0's multi_logloss: 0.0322276
# [51]	valid_0's multi_logloss: 0.0320288
# [52]	valid_0's multi_logloss: 0.0318365
# [53]	valid_0's multi_logloss: 0.0317099
# [54]	valid_0's multi_logloss: 0.0316459
# [55]	valid_0's multi_logloss: 0.031545
# [56]	valid_0's multi_logloss: 0.0314461
# [57]	valid_0's multi_logloss: 0.0313476

# %% [markdown]
# Save the predictions into the same format as required

# %%
# all_preds = pd.concat(predictions)
# all_preds = all_preds.reindex(subm.index)
# all_preds.to_csv('submission.csv')
# all_preds.head(20)

# %% [markdown]
# <h3>Refrences</h3>
#
#
# https://www.kaggle.com/harshsharma511/indoor-location-navigation-eda
#
# https://www.kaggle.com/harshsharma511/basic-eda-traces-and-features-visualization
#
# https://www.kaggle.com/harshsharma511/lightgbm-regressor
